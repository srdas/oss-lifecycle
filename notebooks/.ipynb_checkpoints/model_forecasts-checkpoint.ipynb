# %% [markdown]
# # Generate Forecasts Of Innovation with Partial and Full Data

# %%
import os
import numpy as np
import pandas as pd
import sys
sys.path.append('../oss_lifecycle')
from fit_bass import fitBass, bass, find_zero
from fit_innovation import fitInnovation, prepareDF, plotForecast #dA_dt, model, pct_least_squares,  
from fit_innovation import forecastA, forecastL, polyfit_innovation_timeseries
import matplotlib.pyplot as plt

os.chdir('../')

# %%
def get_developer_params(repo_string, init_life_fraction=1.0):
    """
    Get the project data
    """
    print("Project:", repo_string)
    df = pd.read_csv("data/" + repo_string + "-monthly.csv")
    nobs = int(len(df)*init_life_fraction)
    # Fit the Bass model
    num_devs_df = df[['contributors']][:nobs]
    p, q, m = fitBass(num_devs_df, repo_string, False)
    # Time to end of growth
    t = len(num_devs_df)
    T = find_zero(t, p, q, m)
    yrs = (T-t)/12
    return p, q, m, t, T, yrs

def get_innovation_params(repo_string, init_life_fraction=1.0):
    df = pd.read_csv("data/" + repo_string + "-monthly.csv")
    nobs = int(len(df)*init_life_fraction)
    print("NObs=", nobs)
    num_devs_df = df[['contributors']][:nobs]
    p, q, m = fitBass(num_devs_df, repo_string, False)
    t = np.arange(0, len(df))
    fitted_contributors = bass(p, q, t)[0]*m
    df.loc[:,'contributors'] = fitted_contributors.astype(np.int64) # replace contributors with fitted values
    # Fit innovation data
    df = prepareDF(df)
    # fitted_values, true_values = polyfit_innovation_timeseries(df, repo_string)
    gamma, lam, phi = fitInnovation(df, repo_string, False)
    return gamma, lam, phi, df

# %%
repo_string_list = [
    "dask-dask",
    "huggingface-transformers",
    # "ipython-ipython",
    # "jupyterlab-jupyter-ai",
    "jupyterlab-jupyterlab",
    # "kubeflow-kubeflow",
    "kubernetes-kubernetes",
    "langchain-ai-langchain",
    "numpy-numpy",
    "pandas-dev-pandas",
    "pytorch-pytorch",
    "ray-project-ray",
    # "scikit-learn-scikit-learn",
    "tensorflow-tensorflow",
]

# repo_string_list = ['scikit-learn-scikit-learn']

# %%
# Redo the above to make a single plot with subplots for 5 repos at a time, with both developer engagement and innovation forecasts.
results = pd.DataFrame(columns=['p','q','m','t','T','yrs','p1','q1','m1','t1','T1','yrs1','currDev','currInn','lifeInn','currValue','lifeValue','ratio'])
results2 = pd.DataFrame(columns=['gamma','lambda','phi'])

for repo_string in repo_string_list:
    fig, axs = plt.subplots(1, 2, figsize=(15, 5))

    # Fit Developer Engagement
    p, q, m, t, T, yrs = get_developer_params(repo_string, init_life_fraction=1.0)
    print("p:", p, "q:", q, "m:", m, "t:", t, "T:", T, "yrs:", yrs)
    p1, q1, m1, t1, T1, yrs1 = get_developer_params(repo_string, init_life_fraction=0.75)
    print("p1:", p1, "q1:", q1, "m1:", m1, "t1:", t1, "T1:", T1, "yrs1:", yrs1)

    # Plot Developer engagement from full data and 75% data
    df = pd.read_csv("data/" + repo_string + "-monthly.csv")
    tt = np.arange(len(df))
    axs[0].scatter(tt, df['contributors'])
    axs[0].plot(tt, bass(p, q, tt)[0]*m, color='red', linewidth=2, label='Full data')
    axs[0].plot(tt, bass(p1, q1, tt)[0]*m1, color='green', linewidth=2, label='75% data')
    axs[0].set_title(f"Number of Developers per month [{repo_string}]")
    axs[0].set_xlabel("Months since project start")
    axs[0].legend()
    axs[0].grid(True)
    
    # INNOVATION
    
    # Fit Innovation
    gamma, lam, phi, df = get_innovation_params(repo_string, init_life_fraction=1.0)
    print("gamma:", gamma, "lam:", lam, "phi:", phi)
    gamma1, lam1, phi1, df1 = get_innovation_params(repo_string, init_life_fraction=0.75)
    print("gamma1:", gamma1, "lam1:", lam1, "phi1:", phi1)
    
    # Plot Innovation
    tt = np.arange(len(df))
    L = forecastL(p, q, m, tt)
    A = forecastA(gamma, lam, phi, tt, df['cumInnovation'][0], df["contributors"], L)
    L1 = forecastL(p1, q1, m1, tt)
    A1 = forecastA(gamma1, lam1, phi1, tt, df['cumInnovation'][0], df1["contributors"], L1)

    axs[1].plot(tt, A, label='Full data')
    axs[1].plot(tt, df['cumInnovation'], label='Actual data')
    axs[1].plot(tt, A1, label='75% data')
    axs[1].set_title(f"Cumulative Innovation per month [{repo_string}]")
    axs[1].set_xlabel("Months since project start")
    axs[1].legend()
    axs[1].grid(True)
    
    plt.tight_layout()
    plt.savefig(f"images/{repo_string}_compare_forecasts.png")
    plt.show()

    # get forecasts
    forecast_length = int(T-t) # for no forecast, set to 1 month
    print("Forecast Length =", forecast_length)
    tt = np.arange(len(df)+forecast_length) # added remaining life to forecast
    L = forecastL(p, q, m, tt)
    A = forecastA(gamma, lam, phi, tt, df['cumInnovation'][0], df['contributors'], L)
    plotForecast(A, L, forecast_length, repo_string)
    lifetime_innovation = A[-1]
    print("Total Lifecycle Innovation =", lifetime_innovation)

    # Valuation
    dev_time_invested = 0.50 # assume 50% time only on average
    monthly_salary = 10000
    current_innovation = A[t] # current cumulative innovation
    current_dev_months = df['contributors'].sum()
    innov_dev_ratio = current_innovation/current_dev_months
    # E_i = 2.94*(current_innovation/1000)**1.0997
    currValue = monthly_salary*current_dev_months*dev_time_invested
    lifeValue = monthly_salary*(lifetime_innovation/innov_dev_ratio)*dev_time_invested

    # Add to results
    tmp = pd.DataFrame({"p": p, "q": q, "m": m, "t": t, "T": T, "yrs": yrs, "p1": p1, "q1": q1, "m1": m1, "t1": t1, 
                        "T1": T1, "yrs1": yrs1, "currDev": current_dev_months, "currInn": current_innovation, "lifeInn": lifetime_innovation, 
                        "currValue": currValue, "lifeValue": lifeValue, "ratio": innov_dev_ratio}, index=[repo_string])
    results = pd.concat([results, tmp])
    tmp2 = pd.DataFrame({'gamma':gamma,'lambda':lam,'phi':phi}, index=[repo_string])
    results2 = pd.concat([results2, tmp2])
# Out:
# Project: dask-dask
# Number of periods: 122
# R² = 0.668090
# b0 = 4.580546 ± 0.853588 | t-stat = 5.3662
# b1 = 0.036308 ± 0.002362 | t-stat = 15.3743
# b2 = -1.762340e-05 ± 1.216606e-06 | t-stat = -14.4857
# p: 0.0021016914152666203 q: 0.03840945477226721 m: 2179.4572046800895 t: 122 T: 200.48331598716004 yrs: 6.540276332263336
# Project: dask-dask
# Number of periods: 91
# R² = 0.697822
# b0 = 5.639419 ± 0.990945 | t-stat = 5.6910
# b1 = 0.029356 ± 0.003658 | t-stat = 8.0259
# b2 = -1.174013e-05 ± 2.541156e-06 | t-stat = -4.6200
# p1: 0.002104475775746615 q1: 0.031460327840980046 m1: 2679.726379779156 t1: 91 T1: 236.89243922530235 yrs1: 12.157703268775196
# NObs= 122
# Number of periods: 122
# R² = 0.668090
# b0 = 4.580546 ± 0.853588 | t-stat = 5.3662
# b1 = 0.036308 ± 0.002362 | t-stat = 15.3743
# b2 = -1.762340e-05 ± 1.216606e-06 | t-stat = -14.4857
# Initial obj fn value = 595257.9308318554
# Final obj fn value = 34663.46295424737 ( 5.82 % )
# Solution success: True
# Best-fit parameters:
# gamma = 666550.651
# lambda = -0.542
# phi = -0.243
# gamma: 666550.6514862021 lam: -0.541899085951418 phi: -0.24323824942984534
# NObs= 91
# Number of periods: 91
# R² = 0.697822
# b0 = 5.639419 ± 0.990945 | t-stat = 5.6910
# b1 = 0.029356 ± 0.003658 | t-stat = 8.0259
# b2 = -1.174013e-05 ± 2.541156e-06 | t-stat = -4.6200
# Initial obj fn value = 595244.0252724489
# Final obj fn value = 37288.1364454931 ( 6.26 % )
# Solution success: True
# Best-fit parameters:
# gamma = 3780780.835
# lambda = -0.179
# phi = -0.450
# gamma1: 3780780.8351135785 lam1: -0.17908565521351644 phi1: -0.45013965744910045
# Forecast Length = 78
# Total Lifecycle Innovation = 2035753.5210101027
# Project: huggingface-transformers
# Number of periods: 76
# R² = 0.677876
# b0 = 27.979448 ± 4.717083 | t-stat = 5.9315
# b1 = 0.032365 ± 0.004600 | t-stat = 7.0355
# b2 = -3.377100e-06 ± 8.659283e-07 | t-stat = -3.9000
# p: 0.0026950951747228558 q: 0.03505976067068362 m: 10381.617925894005 t: 76 T: 246.36844677345707 yrs: 14.197370564454756
# Project: huggingface-transformers
# Number of periods: 57
# R² = 0.591674
# b0 = 25.399997 ± 5.702058 | t-stat = 4.4545
# b1 = 0.039195 ± 0.008691 | t-stat = 4.5100
# b2 = -5.557886e-06 ± 2.568299e-06 | t-stat = -2.1640
# p1: 0.003320420479024283 q1: 0.04251578497917455 m1: 7649.632801546 t1: 57 T1: 200.17388487235394 yrs1: 11.93115707269616
# NObs= 76
# Number of periods: 76
# R² = 0.677876
# b0 = 27.979448 ± 4.717083 | t-stat = 5.9315
# b1 = 0.032365 ± 0.004600 | t-stat = 7.0355
# b2 = -3.377100e-06 ± 8.659283e-07 | t-stat = -3.9000
# Initial obj fn value = 3663091.7902183323
# Final obj fn value = 128892.62756235934 ( 3.52 % )
# Solution success: True
# Best-fit parameters:
# gamma = 19799.159
# lambda = -0.949
# phi = 0.372
# gamma: 19799.158901427058 lam: -0.9490521541557755 phi: 0.37162862696167437
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_34960/3706155225.py:76: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results = pd.concat([results, tmp])
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_34960/3706155225.py:78: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   results2 = pd.concat([results2, tmp2])
# NObs= 57
# Number of periods: 57
# R² = 0.591674
# b0 = 25.399997 ± 5.702058 | t-stat = 4.4545
# b1 = 0.039195 ± 0.008691 | t-stat = 4.5100
# b2 = -5.557886e-06 ± 2.568299e-06 | t-stat = -2.1640
# Initial obj fn value = 3663094.271438385
# Final obj fn value = 142734.582939664 ( 3.9 % )
# Solution success: True
# Best-fit parameters:
# gamma = 17986.696
# lambda = -1.022
# phi = 0.398
# gamma1: 17986.695520405156 lam1: -1.0218928936491611 phi1: 0.39772391279360964
# Forecast Length = 170
# Total Lifecycle Innovation = 1774142947.07318
# Project: jupyterlab-jupyterlab
# Number of periods: 116
# R² = 0.493554
# b0 = 9.323643 ± 1.280256 | t-stat = 7.2826
# b1 = 0.030117 ± 0.002871 | t-stat = 10.4918
# b2 = -1.265957e-05 ± 1.255559e-06 | t-stat = -10.0828
# p: 0.003510032916092554 q: 0.033627400519822756 m: 2656.2836240594124 t: 116 T: 205.57311400570032 yrs: 7.464426167141693
# Project: jupyterlab-jupyterlab
# Number of periods: 87
# R² = 0.601373
# b0 = 7.071260 ± 1.348420 | t-stat = 5.2441
# b1 = 0.043506 ± 0.004171 | t-stat = 10.4303
# b2 = -2.180561e-05 ± 2.427975e-06 | t-stat = -8.9810
# p1: 0.0032946666008740843 q1: 0.046800823515713505 m1: 2146.2747230746195 t1: 87 T1: 161.36565602119546 yrs1: 6.197138001766288
# NObs= 116
# Number of periods: 116
# R² = 0.493554
# b0 = 9.323643 ± 1.280256 | t-stat = 7.2826
# b1 = 0.030117 ± 0.002871 | t-stat = 10.4918
# b2 = -1.265957e-05 ± 1.255559e-06 | t-stat = -10.0828
# Initial obj fn value = 6187309.277091181
# Final obj fn value = 533391.873562367 ( 8.62 % )
# Solution success: True
# Best-fit parameters:
# gamma = 73686.070
# lambda = 1.534
# phi = -0.296
# gamma: 73686.06963449766 lam: 1.5335264922138592 phi: -0.2960308954396933
# NObs= 87
# Number of periods: 87
# R² = 0.601373
# b0 = 7.071260 ± 1.348420 | t-stat = 5.2441
# b1 = 0.043506 ± 0.004171 | t-stat = 10.4303
# b2 = -2.180561e-05 ± 2.427975e-06 | t-stat = -8.9810
# Initial obj fn value = 6187323.946747089
# Final obj fn value = 324400.75691576937 ( 5.24 % )
# Solution success: True
# Best-fit parameters:
# gamma = 87748.326
# lambda = 1.491
# phi = -0.295
# gamma1: 87748.32558800341 lam1: 1.4909444400518699 phi1: -0.2946978906937445
# Forecast Length = 89
# Total Lifecycle Innovation = 10218702.311544351
# Project: kubernetes-kubernetes
# Number of periods: 128
# R² = 0.675420
# b0 = 103.140838 ± 6.153151 | t-stat = 16.7623
# b1 = 0.021342 ± 0.001505 | t-stat = 14.1817
# b2 = -1.163056e-06 ± 7.434775e-08 | t-stat = -15.6435
# p: 0.004620430843186475 q: 0.025962646613826326 m: 22322.77492912554 t: 128 T: 297.8089995791794 yrs: 14.150749964931615
# Project: kubernetes-kubernetes
# Number of periods: 96
# R² = 0.706619
# b0 = 89.118986 ± 6.224239 | t-stat = 14.3181
# b1 = 0.029174 ± 0.001951 | t-stat = 14.9525
# b2 = -1.734452e-06 ± 1.213181e-07 | t-stat = -14.2967
# p1: 0.004579497717361295 q1: 0.03375317355696973 m1: 19460.428041755797 t1: 96 T1: 246.03984853182422 yrs1: 12.503320710985351
# NObs= 128
# Number of periods: 128
# R² = 0.675420
# b0 = 103.140838 ± 6.153151 | t-stat = 16.7623
# b1 = 0.021342 ± 0.001505 | t-stat = 14.1817
# b2 = -1.163056e-06 ± 7.434775e-08 | t-stat = -15.6435
# Initial obj fn value = 93799111.52103543
# Final obj fn value = 4698326.712280141 ( 5.01 % )
# Solution success: True
# Best-fit parameters:
# gamma = 17172.653
# lambda = 2.731
# phi = -0.545
# gamma: 17172.65322103683 lam: 2.7310867351616204 phi: -0.5453090362533197
# NObs= 96
# Number of periods: 96
# R² = 0.706619
# b0 = 89.118986 ± 6.224239 | t-stat = 14.3181
# b1 = 0.029174 ± 0.001951 | t-stat = 14.9525
# b2 = -1.734452e-06 ± 1.213181e-07 | t-stat = -14.2967
# Initial obj fn value = 93799131.37303273
# Final obj fn value = 4369223.7133813985 ( 4.66 % )
# Solution success: True
# Best-fit parameters:
# gamma = 230917.284
# lambda = 1.597
# phi = -0.363
# gamma1: 230917.2836548293 lam1: 1.5965438135679846 phi1: -0.36254751743222624
# Forecast Length = 169
# Total Lifecycle Innovation = 135419316.3177768
# Project: langchain-ai-langchain
# Number of periods: 29
# R² = 0.686237
# b0 = 60.563794 ± 18.710378 | t-stat = 3.2369
# b1 = 0.159572 ± 0.021288 | t-stat = 7.4958
# b2 = -3.490110e-05 ± 4.680764e-06 | t-stat = -7.4563
# p: 0.012298456264989372 q: 0.1718705886981669 m: 4924.50373783144 t: 29 T: 55.4304621888698 yrs: 2.2025385157391497
# Project: langchain-ai-langchain
# Number of periods: 21
# R² = 0.716145
# b0 = 50.454103 ± 20.934623 | t-stat = 2.4101
# b1 = 0.193952 ± 0.032235 | t-stat = 6.0169
# b2 = -4.648158e-05 ± 9.371463e-06 | t-stat = -4.9599
# p1: 0.011419264894091702 q1: 0.20537102890437686 m1: 4418.331913398745 t1: 21 T1: 48.436111438180816 yrs1: 2.2863426198484014
# NObs= 29
# Number of periods: 29
# R² = 0.686237
# b0 = 60.563794 ± 18.710378 | t-stat = 3.2369
# b1 = 0.159572 ± 0.021288 | t-stat = 7.4958
# b2 = -3.490110e-05 ± 4.680764e-06 | t-stat = -7.4563
# Initial obj fn value = 6222299.097907923
# Final obj fn value = 481759.3226402775 ( 7.74 % )
# Solution success: True
# Best-fit parameters:
# gamma = 0.018
# lambda = 6.631
# phi = -1.204
# gamma: 0.01756561147117056 lam: 6.630540853331057 phi: -1.2044055286960407
# NObs= 21
# Number of periods: 21
# R² = 0.716145
# b0 = 50.454103 ± 20.934623 | t-stat = 2.4101
# b1 = 0.193952 ± 0.032235 | t-stat = 6.0169
# b2 = -4.648158e-05 ± 9.371463e-06 | t-stat = -4.9599
# Initial obj fn value = 6222302.144697983
# Final obj fn value = 398778.46373347234 ( 6.41 % )
# Solution success: True
# Best-fit parameters:
# gamma = 73.926
# lambda = 3.555
# phi = -0.670
# gamma1: 73.92564532766349 lam1: 3.55457134769243 phi1: -0.6702073858742816
# Forecast Length = 26
# Total Lifecycle Innovation = 8881623.591559444
# Project: numpy-numpy
# Number of periods: 278
# R² = 0.877424
# b0 = 1.839477 ± 0.606591 | t-stat = 3.0325
# b1 = 0.017023 ± 0.000687 | t-stat = 24.7691
# b2 = -1.743197e-06 ± 1.290151e-07 | t-stat = -13.5116
# p: 0.00018633047610007214 q: 0.017209060325730198 m: 9872.123333210251 t: 278 T: 596.1188482508289 yrs: 26.50990402090241
# Project: numpy-numpy
# Number of periods: 208
# R² = 0.845703
# b0 = 1.510852 ± 0.567633 | t-stat = 2.6617
# b1 = 0.019071 ± 0.001267 | t-stat = 15.0487
# b2 = -2.943340e-06 ± 4.779013e-07 | t-stat = -6.1589
# p1: 0.00023039947451330305 q1: 0.019301043259257314 m1: 6557.530966687782 t1: 208 T1: 510.86817601478623 yrs1: 25.239014667898854
# NObs= 278
# Number of periods: 278
# R² = 0.877424
# b0 = 1.839477 ± 0.606591 | t-stat = 3.0325
# b1 = 0.017023 ± 0.000687 | t-stat = 24.7691
# b2 = -1.743197e-06 ± 1.290151e-07 | t-stat = -13.5116
# Initial obj fn value = 9035716.371098675
# Final obj fn value = 985849.8360290432 ( 10.91 % )
# Solution success: True
# Best-fit parameters:
# gamma = 219002.646
# lambda = 0.576
# phi = -0.179
# gamma: 219002.64611997554 lam: 0.5761944909542506 phi: -0.1792794949654949
# NObs= 208
# Number of periods: 208
# R² = 0.845703
# b0 = 1.510852 ± 0.567633 | t-stat = 2.6617
# b1 = 0.019071 ± 0.001267 | t-stat = 15.0487
# b2 = -2.943340e-06 ± 4.779013e-07 | t-stat = -6.1589
# Initial obj fn value = 9035766.195018154
# Final obj fn value = 1048889.7720478666 ( 11.61 % )
# Solution success: True
# Best-fit parameters:
# gamma = 564.778
# lambda = 0.067
# phi = 0.296
# gamma1: 564.7784709087086 lam1: 0.06660224881036526 phi1: 0.29570684426014093
# Forecast Length = 318
# Total Lifecycle Innovation = 30966164.430793047
# Project: pandas-dev-pandas
# Number of periods: 187
# R² = 0.748828
# b0 = 7.128920 ± 1.689969 | t-stat = 4.2184
# b1 = 0.027548 ± 0.001400 | t-stat = 19.6767
# b2 = -3.118501e-06 ± 2.003451e-07 | t-stat = -15.5656
# p: 0.0007846619272907747 q: 0.02833264000123583 m: 9085.339784400301 t: 187 T: 339.36139750841323 yrs: 12.696783125701103
# Project: pandas-dev-pandas
# Number of periods: 140
# R² = 0.776036
# b0 = 7.001962 ± 1.861933 | t-stat = 3.7606
# b1 = 0.027125 ± 0.002400 | t-stat = 11.3012
# b2 = -2.815319e-06 ± 5.396123e-07 | t-stat = -5.2173
# p1: 0.0007082497699129891 q1: 0.02783305756677858 m1: 9886.28845519064 t1: 140 T1: 351.3677251847595 yrs1: 17.613977098729958
# NObs= 187
# Number of periods: 187
# R² = 0.748828
# b0 = 7.128920 ± 1.689969 | t-stat = 4.2184
# b1 = 0.027548 ± 0.001400 | t-stat = 19.6767
# b2 = -3.118501e-06 ± 2.003451e-07 | t-stat = -15.5656
# Initial obj fn value = 4270636.109316743
# Final obj fn value = 177631.0408764833 ( 4.16 % )
# Solution success: True
# Best-fit parameters:
# gamma = 143333165.608
# lambda = 1.707
# phi = -0.977
# gamma: 143333165.60800493 lam: 1.7069919680419217 phi: -0.9769185572642418
# NObs= 140
# Number of periods: 140
# R² = 0.776036
# b0 = 7.001962 ± 1.861933 | t-stat = 3.7606
# b1 = 0.027125 ± 0.002400 | t-stat = 11.3012
# b2 = -2.815319e-06 ± 5.396123e-07 | t-stat = -5.2173
# Initial obj fn value = 4270632.254287076
# Final obj fn value = 219977.5929197389 ( 5.15 % )
# Solution success: True
# Best-fit parameters:
# gamma = 163445300.769
# lambda = 1.525
# phi = -0.942
# gamma1: 163445300.76949626 lam1: 1.5253597168513036 phi1: -0.9418985351790327
# Forecast Length = 152
# Total Lifecycle Innovation = 7360241.719755777
# Project: pytorch-pytorch
# Number of periods: 157
# R² = 0.925943
# b0 = 18.288359 ± 3.141727 | t-stat = 5.8211
# b1 = 0.033066 ± 0.001268 | t-stat = 26.0821
# b2 = -1.198790e-06 ± 8.118771e-08 | t-stat = -14.7657
# p: 0.0006502429231887941 q: 0.03371648715139511 m: 28125.42528982028 t: 157 T: 335.5976118403597 yrs: 14.883134320029976
# Project: pytorch-pytorch
# Number of periods: 117
# R² = 0.933118
# b0 = 7.612082 ± 2.654017 | t-stat = 2.8681
# b1 = 0.052902 ± 0.002376 | t-stat = 22.2662
# b2 = -3.638248e-06 ± 3.105633e-07 | t-stat = -11.7150
# p1: 0.0005184252367220575 q1: 0.05342071123552253 m1: 14683.08619227252 t1: 117 T1: 222.68179641466645 yrs1: 8.806816367888871
# NObs= 157
# Number of periods: 157
# R² = 0.925943
# b0 = 18.288359 ± 3.141727 | t-stat = 5.8211
# b1 = 0.033066 ± 0.001268 | t-stat = 26.0821
# b2 = -1.198790e-06 ± 8.118771e-08 | t-stat = -14.7657
# Initial obj fn value = 9614312.656205157
# Final obj fn value = 440503.26040384785 ( 4.58 % )
# Solution success: True
# Best-fit parameters:
# gamma = 12.860
# lambda = 0.281
# phi = 0.512
# gamma: 12.860418289216561 lam: 0.28130882700605353 phi: 0.5119140002170643
# NObs= 117
# Number of periods: 117
# R² = 0.933118
# b0 = 7.612082 ± 2.654017 | t-stat = 2.8681
# b1 = 0.052902 ± 0.002376 | t-stat = 22.2662
# b2 = -3.638248e-06 ± 3.105633e-07 | t-stat = -11.7150
# Initial obj fn value = 9614442.196579924
# Final obj fn value = 423358.15139072406 ( 4.4 % )
# Solution success: True
# Best-fit parameters:
# gamma = 6.325
# lambda = 0.094
# phi = 0.623
# gamma1: 6.3254199582660515 lam1: 0.09375282271738691 phi1: 0.62295700937189
# Forecast Length = 178
# Total Lifecycle Innovation = 61166581.33676643
# Project: ray-project-ray
# Number of periods: 108
# R² = 0.926776
# b0 = 5.659930 ± 1.136319 | t-stat = 4.9809
# b1 = 0.048065 ± 0.001660 | t-stat = 28.9473
# b2 = -9.133276e-06 ± 4.121212e-07 | t-stat = -22.1616
# p: 0.001052457590947915 q: 0.04911713878220989 m: 5377.8227009957145 t: 108 T: 202.34331808457273 yrs: 7.861943173714394
# Project: ray-project-ray
# Number of periods: 81
# R² = 0.947175
# b0 = 4.656580 ± 1.135059 | t-stat = 4.1025
# b1 = 0.051116 ± 0.002642 | t-stat = 19.3506
# b2 = -9.916437e-06 ± 1.040975e-06 | t-stat = -9.5261
# p1: 0.0008879393168119499 q1: 0.05200432479764479 m1: 5244.255163145941 t1: 81 T1: 196.66566638873724 yrs1: 9.63880553239477
# NObs= 108
# Number of periods: 108
# R² = 0.926776
# b0 = 5.659930 ± 1.136319 | t-stat = 4.9809
# b1 = 0.048065 ± 0.001660 | t-stat = 28.9473
# b2 = -9.133276e-06 ± 4.121212e-07 | t-stat = -22.1616
# Initial obj fn value = 4001797.448495285
# Final obj fn value = 155581.15693630662 ( 3.89 % )
# Solution success: True
# Best-fit parameters:
# gamma = 1665.112
# lambda = 0.916
# phi = 0.030
# gamma: 1665.1121892439667 lam: 0.9161499060119696 phi: 0.0300968420795654
# NObs= 81
# Number of periods: 81
# R² = 0.947175
# b0 = 4.656580 ± 1.135059 | t-stat = 4.1025
# b1 = 0.051116 ± 0.002642 | t-stat = 19.3506
# b2 = -9.916437e-06 ± 1.040975e-06 | t-stat = -9.5261
# Initial obj fn value = 4001810.8580393572
# Final obj fn value = 152122.2090995747 ( 3.8 % )
# Solution success: True
# Best-fit parameters:
# gamma = 2843.472
# lambda = 0.866
# phi = 0.008
# gamma1: 2843.472160051906 lam1: 0.8658697395873534 phi1: 0.008088641004952792
# Forecast Length = 94
# Total Lifecycle Innovation = 10272168.00285002
# Project: tensorflow-tensorflow
# Number of periods: 111
# R² = 0.762599
# b0 = 100.509695 ± 6.407397 | t-stat = 15.6865
# b1 = 0.027548 ± 0.001480 | t-stat = 18.6097
# b2 = -1.195418e-06 ± 6.711443e-08 | t-stat = -17.8116
# p: 0.0038292699770463737 q: 0.0313770337338905 m: 26247.743087261697 t: 111 T: 276.6418832651693 yrs: 13.803490272097443
# Project: tensorflow-tensorflow
# Number of periods: 83
# R² = 0.895163
# b0 = 77.751506 ± 5.282940 | t-stat = 14.7175
# b1 = 0.040118 ± 0.001665 | t-stat = 24.0954
# b2 = -2.080069e-06 ± 1.002783e-07 | t-stat = -20.7430
# p1: 0.003691587592275648 q1: 0.04381000680047285 m1: 21061.807219324637 t1: 83 T1: 213.78558092602364 yrs1: 10.89879841050197
# NObs= 111
# Number of periods: 111
# R² = 0.762599
# b0 = 100.509695 ± 6.407397 | t-stat = 15.6865
# b1 = 0.027548 ± 0.001480 | t-stat = 18.6097
# b2 = -1.195418e-06 ± 6.711443e-08 | t-stat = -17.8116
# Initial obj fn value = 290604844.35719556
# Final obj fn value = 31403515.088211402 ( 10.81 % )
# Solution success: True
# Best-fit parameters:
# gamma = 0.000
# lambda = 7.043
# phi = -0.398
# gamma: 2.355123055698222e-07 lam: 7.042639365468657 phi: -0.3981448885859798
# NObs= 83
# Number of periods: 83
# R² = 0.895163
# b0 = 77.751506 ± 5.282940 | t-stat = 14.7175
# b1 = 0.040118 ± 0.001665 | t-stat = 24.0954
# b2 = -2.080069e-06 ± 1.002783e-07 | t-stat = -20.7430
# Initial obj fn value = 290604871.07605714
# Final obj fn value = 15976164.361243937 ( 5.5 % )
# Solution success: True
# Best-fit parameters:
# gamma = 469.534
# lambda = 1.754
# phi = -0.005
# gamma1: 469.53424559167814 lam1: 1.753589894544206 phi1: -0.004936008738330593
# Forecast Length = 165
# Total Lifecycle Innovation = 451638922.03429395

# %%
results
# Out:
#                                  p         q             m    t           T  \
# dask-dask                 0.002102  0.038409   2179.457205  122  200.483316
# huggingface-transformers  0.002695  0.035060  10381.617926   76  246.368447
# jupyterlab-jupyterlab     0.003510  0.033627   2656.283624  116  205.573114
# kubernetes-kubernetes     0.004620  0.025963  22322.774929  128  297.809000
# langchain-ai-langchain    0.012298  0.171871   4924.503738   29   55.430462
# numpy-numpy               0.000186  0.017209   9872.123333  278  596.118848
# pandas-dev-pandas         0.000785  0.028333   9085.339784  187  339.361398
# pytorch-pytorch           0.000650  0.033716  28125.425290  157  335.597612
# ray-project-ray           0.001052  0.049117   5377.822701  108  202.343318
# tensorflow-tensorflow     0.003829  0.031377  26247.743087  111  276.641883
#
#                                 yrs        p1        q1            m1   t1  \
# dask-dask                  6.540276  0.002104  0.031460   2679.726380   91
# huggingface-transformers  14.197371  0.003320  0.042516   7649.632802   57
# jupyterlab-jupyterlab      7.464426  0.003295  0.046801   2146.274723   87
# kubernetes-kubernetes     14.150750  0.004579  0.033753  19460.428042   96
# langchain-ai-langchain     2.202539  0.011419  0.205371   4418.331913   21
# numpy-numpy               26.509904  0.000230  0.019301   6557.530967  208
# pandas-dev-pandas         12.696783  0.000708  0.027833   9886.288455  140
# pytorch-pytorch           14.883134  0.000518  0.053421  14683.086192  117
# ray-project-ray            7.861943  0.000888  0.052004   5244.255163   81
# tensorflow-tensorflow     13.803490  0.003692  0.043810  21061.807219   83
#
#                                   T1       yrs1 currDev       currInn  \
# dask-dask                 236.892439  12.157703    1851  9.132355e+05
# huggingface-transformers  200.173885  11.931157    5557  6.297433e+06
# jupyterlab-jupyterlab     161.365656   6.197138    2265  9.706089e+06
# kubernetes-kubernetes     246.039849  12.503321   19627  1.342954e+08
# langchain-ai-langchain     48.436111   2.286343    4578  8.881573e+06
# numpy-numpy               510.868176  25.239015    5495  1.831228e+07
# pandas-dev-pandas         351.367725  17.613977    7707  7.102754e+06
# pytorch-pytorch           222.681796   8.806816   22518  2.311608e+07
# ray-project-ray           196.665666   9.638806    4369  8.244649e+06
# tensorflow-tensorflow     213.785581  10.898798   22021  4.513363e+08
#
#                                lifeInn    currValue     lifeValue  \
# dask-dask                 2.035754e+06    9255000.0  2.063093e+07
# huggingface-transformers  1.774143e+09   27785000.0  7.827724e+09
# jupyterlab-jupyterlab     1.021870e+07   11325000.0  1.192311e+07
# kubernetes-kubernetes     1.354193e+08   98135000.0  9.895627e+07
# langchain-ai-langchain    8.881624e+06   22890000.0  2.289013e+07
# numpy-numpy               3.096616e+07   27475000.0  4.646037e+07
# pandas-dev-pandas         7.360242e+06   38535000.0  3.993197e+07
# pytorch-pytorch           6.116658e+07  112590000.0  2.979201e+08
# ray-project-ray           1.027217e+07   21845000.0  2.721711e+07
# tensorflow-tensorflow     4.516389e+08  110105000.0  1.101788e+08
#
#                                  ratio
# dask-dask                   493.374143
# huggingface-transformers   1133.243218
# jupyterlab-jupyterlab      4285.248937
# kubernetes-kubernetes      6842.382074
# langchain-ai-langchain     1940.055257
# numpy-numpy                3332.535333
# pandas-dev-pandas           921.597714
# pytorch-pytorch            1026.560014
# ray-project-ray            1887.079221
# tensorflow-tensorflow     20495.723406

# %%
# TABLE III
results1 = results.copy()[['t','T','currDev','currInn','lifeInn','ratio','currValue','lifeValue']]
results1
# Out:
#                             t           T currDev       currInn       lifeInn  \
# dask-dask                 122  200.483316    1851  9.132355e+05  2.035754e+06
# huggingface-transformers   76  246.368447    5557  6.297433e+06  1.774143e+09
# jupyterlab-jupyterlab     116  205.573114    2265  9.706089e+06  1.021870e+07
# kubernetes-kubernetes     128  297.809000   19627  1.342954e+08  1.354193e+08
# langchain-ai-langchain     29   55.430462    4578  8.881573e+06  8.881624e+06
# numpy-numpy               278  596.118848    5495  1.831228e+07  3.096616e+07
# pandas-dev-pandas         187  339.361398    7707  7.102754e+06  7.360242e+06
# pytorch-pytorch           157  335.597612   22518  2.311608e+07  6.116658e+07
# ray-project-ray           108  202.343318    4369  8.244649e+06  1.027217e+07
# tensorflow-tensorflow     111  276.641883   22021  4.513363e+08  4.516389e+08
#
#                                  ratio    currValue     lifeValue
# dask-dask                   493.374143    9255000.0  2.063093e+07
# huggingface-transformers   1133.243218   27785000.0  7.827724e+09
# jupyterlab-jupyterlab      4285.248937   11325000.0  1.192311e+07
# kubernetes-kubernetes      6842.382074   98135000.0  9.895627e+07
# langchain-ai-langchain     1940.055257   22890000.0  2.289013e+07
# numpy-numpy                3332.535333   27475000.0  4.646037e+07
# pandas-dev-pandas           921.597714   38535000.0  3.993197e+07
# pytorch-pytorch            1026.560014  112590000.0  2.979201e+08
# ray-project-ray            1887.079221   21845000.0  2.721711e+07
# tensorflow-tensorflow     20495.723406  110105000.0  1.101788e+08

# %%
# Format the last 4 columns in thousands with two decimal places
results1[['T','currDev']] = results1[['T','currDev']].map(lambda x: f'{x:.0f}')
results1[['ratio']] = results1[['ratio']].map(lambda x: f'{x:.2f}')
results1[['currInn', 'lifeInn', 'currValue', 'lifeValue']] = results1[['currInn', 'lifeInn', 'currValue', 'lifeValue']].map(lambda x: f'{x/1000000:.2f}')

# Convert the DataFrame to LaTeX format
latex_code = results1.to_latex(index=True)
print(latex_code)
# Out:
# \begin{tabular}{lllllllll}
# \toprule
#  & t & T & currDev & currInn & lifeInn & ratio & currValue & lifeValue \\
# \midrule
# dask-dask & 122 & 200 & 1851 & 0.91 & 2.04 & 493.37 & 9.26 & 20.63 \\
# huggingface-transformers & 76 & 246 & 5557 & 6.30 & 1774.14 & 1133.24 & 27.79 & 7827.72 \\
# jupyterlab-jupyterlab & 116 & 206 & 2265 & 9.71 & 10.22 & 4285.25 & 11.32 & 11.92 \\
# kubernetes-kubernetes & 128 & 298 & 19627 & 134.30 & 135.42 & 6842.38 & 98.14 & 98.96 \\
# langchain-ai-langchain & 29 & 55 & 4578 & 8.88 & 8.88 & 1940.06 & 22.89 & 22.89 \\
# numpy-numpy & 278 & 596 & 5495 & 18.31 & 30.97 & 3332.54 & 27.48 & 46.46 \\
# pandas-dev-pandas & 187 & 339 & 7707 & 7.10 & 7.36 & 921.60 & 38.53 & 39.93 \\
# pytorch-pytorch & 157 & 336 & 22518 & 23.12 & 61.17 & 1026.56 & 112.59 & 297.92 \\
# ray-project-ray & 108 & 202 & 4369 & 8.24 & 10.27 & 1887.08 & 21.84 & 27.22 \\
# tensorflow-tensorflow & 111 & 277 & 22021 & 451.34 & 451.64 & 20495.72 & 110.11 & 110.18 \\
# \bottomrule
# \end{tabular}

# %%
# TABLE I
results3 = results2.copy()
results3[['lambda','phi']] = results3[['lambda','phi']].map(lambda x: f'{x:.4f}')
results3[['gamma']] = results3[['gamma']].map(lambda x: f'{x:.2f}')
results3
# Out:
#                                  gamma   lambda      phi
# dask-dask                    666550.65  -0.5419  -0.2432
# huggingface-transformers      19799.16  -0.9491   0.3716
# jupyterlab-jupyterlab         73686.07   1.5335  -0.2960
# kubernetes-kubernetes         17172.65   2.7311  -0.5453
# langchain-ai-langchain            0.02   6.6305  -1.2044
# numpy-numpy                  219002.65   0.5762  -0.1793
# pandas-dev-pandas         143333165.61   1.7070  -0.9769
# pytorch-pytorch                  12.86   0.2813   0.5119
# ray-project-ray                1665.11   0.9161   0.0301
# tensorflow-tensorflow             0.00   7.0426  -0.3981

# %%
# Convert the DataFrame to LaTeX format
latex_code = results3.to_latex(index=True)
print(latex_code)
# Out:
# \begin{tabular}{llll}
# \toprule
#  & gamma & lambda & phi \\
# \midrule
# dask-dask & 666550.65 & -0.5419 & -0.2432 \\
# huggingface-transformers & 19799.16 & -0.9491 & 0.3716 \\
# jupyterlab-jupyterlab & 73686.07 & 1.5335 & -0.2960 \\
# kubernetes-kubernetes & 17172.65 & 2.7311 & -0.5453 \\
# langchain-ai-langchain & 0.02 & 6.6305 & -1.2044 \\
# numpy-numpy & 219002.65 & 0.5762 & -0.1793 \\
# pandas-dev-pandas & 143333165.61 & 1.7070 & -0.9769 \\
# pytorch-pytorch & 12.86 & 0.2813 & 0.5119 \\
# ray-project-ray & 1665.11 & 0.9161 & 0.0301 \\
# tensorflow-tensorflow & 0.00 & 7.0426 & -0.3981 \\
# \bottomrule
# \end{tabular}
