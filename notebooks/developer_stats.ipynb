# %% [markdown]
# # Generate all developer stats
#
# Collects model data about the developers in all projects.
# This gets the following for each project and creates a latex table:
# 1. p: coefficient of independent propensity to join the project
# 2. q: coefficient of network intensity to join the project
# 3. m: calibrated developer-months expected over the project's lifetime
# 4. t: current life of project in months
# 5. T: expected lifetime of project in months
# 6. yrs: expected remaining lifetime of project in years

# %%
import os
import numpy as np
import pandas as pd
import sys
sys.path.append('../src')
import fit_bass
import matplotlib.pyplot as plt

# Months between two dates in YYYY-MM-DD str format
def months_between(start_date, end_date):
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    return (end.year - start.year) * 12 + end.month - start.month

os.chdir('../')

# %%
# Get list of projects for which data files have been collected

project_files = os.listdir("data")
projects_list = []
for file in project_files:
    if file.endswith("-monthly.csv"):
        projects_list.append(file.split("-monthly")[0])

print("Projects:", projects_list)
# Out:
# Projects: ['vllm-project-vllm', 'scikit-learn-scikit-learn', 'pandas-dev-pandas', 'kubernetes-sigs-kueue', 'langchain-ai-langchain-google', 'jax-ml-jax', 'dask-dask', 'kubernetes-kubernetes', 'numpy-numpy', 'kubeflow-kubeflow', 'ray-project-ray', 'tensorflow-tensorflow', 'jupyterlab-jupyter-ai', 'microsoft-DeepSpeed', 'ipython-ipython', 'pytorch-pytorch', 'huggingface-transformers', 'langchain-ai-langchain-aws', 'langchain-ai-langchain', 'run-llama-llama_index', 'mlflow-mlflow', 'jupyterlab-jupyterlab', 'jupyter-server-jupyter-scheduler']

# %%
# Collect stats by project
df = pd.DataFrame(columns=["Project", "Start_Date", "End_Date", "p", "q", "m", "t", "T", "yrs"])
for project in projects_list:
    start_date, end_date, p, q, m, t, T, yrs = fit_bass.get_project_developer_model_stats(project)
    df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date, 
                                       "p": p, "q": q, "m": m, "t": t, "T": T, "yrs": yrs}])], ignore_index=True)
# Out:
# Project: vllm-project-vllm
# Number of periods: 24
# p=0.002385473764120877, q=0.19421649512836917, m=2524.361813119421
# Time of zero growth: 57.52794217745348 months
# Remaining months = 33.52794217745348  = 2.793995181454457 years
# Project: scikit-learn-scikit-learn
# Number of periods: 181
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_35166/240030380.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date,
# p=0.0016398212629878434, q=0.017463884095220532, m=9697.097916237213
# Time of zero growth: 437.883539304387 months
# Remaining months = 256.883539304387  = 21.406961608698918 years
# Project: pandas-dev-pandas
# Number of periods: 187
# p=0.0007846619272907747, q=0.02833264000123583, m=9085.339784400301
# Time of zero growth: 339.36139750841323 months
# Remaining months = 152.36139750841323  = 12.696783125701103 years
# Project: kubernetes-sigs-kueue
# Number of periods: 39
# p=0.0037096100663804557, q=0.0846467772078926, m=920.7060064795205
# Time of zero growth: 93.37730210892265 months
# Remaining months = 54.37730210892265  = 4.531441842410221 years
# Project: langchain-ai-langchain-google
# Number of periods: 13
# p=0.03914592344784144, q=0.23507026411149182, m=235.98312312631725
# Time of zero growth: 24.78449056656688 months
# Remaining months = 11.78449056656688  = 0.98204088054724 years
# Project: jax-ml-jax
# Number of periods: 75
# /Users/sanjivda/GitHub/open-source/notebooks/../src/fit_bass.py:46: RuntimeWarning: invalid value encountered in sqrt
#   m1 = (-b1 + np.sqrt(b1**2 - 4*b2*b0))/(2*b2)
# /Users/sanjivda/GitHub/open-source/notebooks/../src/fit_bass.py:47: RuntimeWarning: invalid value encountered in sqrt
#   m2 = (-b1 - np.sqrt(b1**2 - 4*b2*b0))/(2*b2)
# p=nan, q=nan, m=nan
# Time of zero growth: 75.0 months
# Remaining months = 0.0  = 0.0 years
# Project: dask-dask
# Number of periods: 122
# /Users/sanjivda/GitHub/open-source/notebooks/../src/fit_bass.py:88: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   t_zero = fsolve(solve_for_zero, t_initial_guess, args=(p, q, m))
# p=0.0021016914152666203, q=0.03840945477226721, m=2179.4572046800895
# Time of zero growth: 200.48331598716004 months
# Remaining months = 78.48331598716004  = 6.540276332263336 years
# Project: kubernetes-kubernetes
# Number of periods: 128
# p=0.004620430843186475, q=0.025962646613826326, m=22322.77492912554
# Time of zero growth: 297.8089995791794 months
# Remaining months = 169.80899957917939  = 14.150749964931615 years
# Project: numpy-numpy
# Number of periods: 278
# p=0.00018633047610007214, q=0.017209060325730198, m=9872.123333210251
# Time of zero growth: 596.1188482508289 months
# Remaining months = 318.11884825082893  = 26.50990402090241 years
# Project: kubeflow-kubeflow
# Number of periods: 85
# p=0.022234938417378475, q=0.024890092251485692, m=888.737640798044
# Time of zero growth: 109.63188057142949 months
# Remaining months = 24.63188057142949  = 2.0526567142857908 years
# Project: ray-project-ray
# Number of periods: 108
# p=0.001052457590947915, q=0.04911713878220989, m=5377.8227009957145
# Time of zero growth: 202.34331808457273 months
# Remaining months = 94.34331808457273  = 7.861943173714394 years
# Project: tensorflow-tensorflow
# Number of periods: 111
# p=0.0038292699770463737, q=0.0313770337338905, m=26247.743087261697
# Time of zero growth: 276.6418832651693 months
# Remaining months = 165.64188326516933  = 13.803490272097443 years
# Project: jupyterlab-jupyter-ai
# Number of periods: 24
# p=0.013895627811045716, q=0.12720007241001102, m=229.97932264043715
# Time of zero growth: 45.80085638023296 months
# Remaining months = 21.800856380232958  = 1.8167380316860797 years
# Project: microsoft-DeepSpeed
# Number of periods: 61
# p=0.00211778723453899, q=0.0670466573591825, m=1557.261184011525
# Time of zero growth: 127.9503710588338 months
# Remaining months = 66.9503710588338  = 5.579197588236149 years
# Project: ipython-ipython
# Number of periods: 235
# p=0.0013868554341335442, q=0.026444713353934647, m=2724.4281965060923
# Time of zero growth: 287.7329081370075 months
# Remaining months = 52.732908137007485  = 4.394409011417291 years
# Project: pytorch-pytorch
# Number of periods: 157
# p=0.0006502429231887941, q=0.03371648715139511, m=28125.42528982028
# Time of zero growth: 335.5976118403597 months
# Remaining months = 178.59761184035972  = 14.883134320029976 years
# Project: huggingface-transformers
# Number of periods: 76
# p=0.0026950951747228558, q=0.03505976067068362, m=10381.617925894005
# Time of zero growth: 246.36844677345707 months
# Remaining months = 170.36844677345707  = 14.197370564454756 years
# Project: langchain-ai-langchain-aws
# Number of periods: 11
# p=0.0379543818142496, q=0.2815859673199854, m=80.22511260916782
# Time of zero growth: 18.87809606281333 months
# Remaining months = 7.878096062813331  = 0.6565080052344442 years
# Project: langchain-ai-langchain
# Number of periods: 28
# p=0.011974997405668087, q=0.18073899267837729, m=4799.893803699562
# Time of zero growth: 53.448738830305984 months
# Remaining months = 25.448738830305984  = 2.120728235858832 years
# Project: run-llama-llama_index
# Number of periods: 27
# p=0.004475997832453511, q=0.19167563052863573, m=2535.012106250584
# Time of zero growth: 54.44983678604827 months
# Remaining months = 27.449836786048273  = 2.287486398837356 years
# Project: mlflow-mlflow
# Number of periods: 80
# p=0.0025774256062681745, q=0.014094945174713113, m=6374.447421874977
# Time of zero growth: 432.94122925064187 months
# Remaining months = 352.94122925064187  = 29.411769104220156 years
# Project: jupyterlab-jupyterlab
# Number of periods: 115
# p=0.003507133708212629, q=0.03380614251462469, m=2648.2169544350786
# Time of zero growth: 204.79843241157 months
# Remaining months = 89.79843241156999  = 7.483202700964166 years
# Project: jupyter-server-jupyter-scheduler
# Number of periods: 27
# /Users/sanjivda/GitHub/open-source/notebooks/../src/fit_bass.py:46: RuntimeWarning: invalid value encountered in sqrt
#   m1 = (-b1 + np.sqrt(b1**2 - 4*b2*b0))/(2*b2)
# /Users/sanjivda/GitHub/open-source/notebooks/../src/fit_bass.py:47: RuntimeWarning: invalid value encountered in sqrt
#   m2 = (-b1 - np.sqrt(b1**2 - 4*b2*b0))/(2*b2)
# p=nan, q=nan, m=nan
# Time of zero growth: 27.0 months
# Remaining months = 0.0  = 0.0 years
# /Users/sanjivda/GitHub/open-source/notebooks/../src/fit_bass.py:88: RuntimeWarning: The iteration is not making good progress, as measured by the
#  improvement from the last ten iterations.
#   t_zero = fsolve(solve_for_zero, t_initial_guess, args=(p, q, m))

# %%
# TABLE II
# Export to Latex
df = df.sort_values(by="Project")
print(df.round(5).to_latex(float_format="%.5f", index=False))
# Out:
# \begin{tabular}{lllrrrlrr}
# \toprule
# Project & Start_Date & End_Date & p & q & m & t & T & yrs \\
# \midrule
# dask-dask & 2014-12-31 & 2025-01-31 & 0.00210 & 0.03841 & 2179.45720 & 122 & 200.48332 & 6.54028 \\
# huggingface-transformers & 2018-10-31 & 2025-01-31 & 0.00270 & 0.03506 & 10381.61793 & 76 & 246.36845 & 14.19737 \\
# ipython-ipython & 2005-07-31 & 2025-01-31 & 0.00139 & 0.02644 & 2724.42820 & 235 & 287.73291 & 4.39441 \\
# jax-ml-jax & 2018-11-30 & 2025-01-31 & NaN & NaN & NaN & 75 & 75.00000 & 0.00000 \\
# jupyter-server-jupyter-scheduler & 2022-09-30 & 2024-11-30 & NaN & NaN & NaN & 27 & 27.00000 & 0.00000 \\
# jupyterlab-jupyter-ai & 2023-02-28 & 2025-01-31 & 0.01390 & 0.12720 & 229.97932 & 24 & 45.80086 & 1.81674 \\
# jupyterlab-jupyterlab & 2015-07-31 & 2025-01-31 & 0.00351 & 0.03381 & 2648.21695 & 115 & 204.79843 & 7.48320 \\
# kubeflow-kubeflow & 2017-11-30 & 2024-11-30 & 0.02223 & 0.02489 & 888.73764 & 85 & 109.63188 & 2.05266 \\
# kubernetes-kubernetes & 2014-06-30 & 2025-01-31 & 0.00462 & 0.02596 & 22322.77493 & 128 & 297.80900 & 14.15075 \\
# kubernetes-sigs-kueue & 2021-11-30 & 2025-01-31 & 0.00371 & 0.08465 & 920.70601 & 39 & 93.37730 & 4.53144 \\
# langchain-ai-langchain & 2022-10-31 & 2025-01-31 & 0.01197 & 0.18074 & 4799.89380 & 28 & 53.44874 & 2.12073 \\
# langchain-ai-langchain-aws & 2024-03-31 & 2025-01-31 & 0.03795 & 0.28159 & 80.22511 & 11 & 18.87810 & 0.65651 \\
# langchain-ai-langchain-google & 2024-02-29 & 2025-02-28 & 0.03915 & 0.23507 & 235.98312 & 13 & 24.78449 & 0.98204 \\
# microsoft-DeepSpeed & 2020-01-31 & 2025-01-31 & 0.00212 & 0.06705 & 1557.26118 & 61 & 127.95037 & 5.57920 \\
# mlflow-mlflow & 2018-06-30 & 2025-01-31 & 0.00258 & 0.01409 & 6374.44742 & 80 & 432.94123 & 29.41177 \\
# numpy-numpy & 2001-12-31 & 2025-01-31 & 0.00019 & 0.01721 & 9872.12333 & 278 & 596.11885 & 26.50990 \\
# pandas-dev-pandas & 2009-07-31 & 2025-01-31 & 0.00078 & 0.02833 & 9085.33978 & 187 & 339.36140 & 12.69678 \\
# pytorch-pytorch & 2012-01-31 & 2025-01-31 & 0.00065 & 0.03372 & 28125.42529 & 157 & 335.59761 & 14.88313 \\
# ray-project-ray & 2016-02-29 & 2025-01-31 & 0.00105 & 0.04912 & 5377.82270 & 108 & 202.34332 & 7.86194 \\
# run-llama-llama_index & 2022-11-30 & 2025-01-31 & 0.00448 & 0.19168 & 2535.01211 & 27 & 54.44984 & 2.28749 \\
# scikit-learn-scikit-learn & 2010-01-31 & 2025-01-31 & 0.00164 & 0.01746 & 9697.09792 & 181 & 437.88354 & 21.40696 \\
# tensorflow-tensorflow & 2015-11-30 & 2025-01-31 & 0.00383 & 0.03138 & 26247.74309 & 111 & 276.64188 & 13.80349 \\
# vllm-project-vllm & 2023-02-28 & 2025-01-31 & 0.00239 & 0.19422 & 2524.36181 & 24 & 57.52794 & 2.79400 \\
# \bottomrule
# \end{tabular}

# %%
# Export to CSV
df.to_csv("data/developer_stats.csv", index=False)
df = df.dropna()

# %%
# FIGURE 5
# Make combined plot of all projects
earliest_start = df['Start_Date'].min() # Get earliest start date of all projects

plt.figure(figsize=(15, 6))
start_datetime = pd.to_datetime(earliest_start)
color_num = 0
for index, row in df.iterrows():
    color_num += 1

    # Get time when series starts in span
    start_offset = months_between(earliest_start, row["Start_Date"])

    # Get the project life cycle so far
    t_list = np.arange(0, int(row["t"]))
    f, _ = fit_bass.bass(row["p"], row["q"], t_list)
    t_list = t_list + start_offset
    datetime_list = [start_datetime + pd.DateOffset(months=offset) for offset in t_list]
    plt.plot(datetime_list, f*row["m"], linewidth=2, label=row["Project"], color=plt.cm.tab20(color_num % 20))

    # Get the project life cycle from now to end
    t_list = np.arange(int(row["t"]), int(row["T"]))
    f, _ = fit_bass.bass(row["p"], row["q"], t_list)
    t_list = t_list + start_offset
    datetime_list = [start_datetime + pd.DateOffset(months=offset) for offset in t_list]
    plt.plot(datetime_list, f*row["m"], linewidth=2, ls='--', color=plt.cm.tab20(color_num % 20))
    plt.legend()
plt.xlabel('Date')
plt.ylabel('No. of Developers making contributions in each month')
plt.title('Developer engagement for selected projects')
plt.grid()
plt.savefig(f"images/all_project_lifecycles.png")
plt.show()
