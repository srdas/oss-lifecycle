# %% [markdown]
# # Generate all developer stats
#
# Collects model data about the developers in all projects.
# This gets the following for each project and creates a latex table:
# 1. p: coefficient of independent propensity to join the project
# 2. q: coefficient of network intensity to join the project
# 3. m: calibrated developer-months expected over the project's lifetime
# 4. t: current life of project in months
# 5. T: expected lifetime of project in months
# 6. yrs: expected remaining lifetime of project in years

# %%
import os
import numpy as np
import pandas as pd
import sys
sys.path.append('../oss_lifecycle')
import fit_bass
import matplotlib.pyplot as plt

# Months between two dates in YYYY-MM-DD str format
def months_between(start_date, end_date):
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    return (end.year - start.year) * 12 + end.month - start.month

os.chdir('../')

# %%
# Get list of projects for which data files have been collected

project_files = os.listdir("data")
projects_list = []
for file in project_files:
    if file.endswith("-monthly.csv"):
        projects_list.append(file.split("-monthly")[0])

print("Projects:", projects_list)
# Out:
# Projects: ['vllm-project-vllm', 'scikit-learn-scikit-learn', 'pandas-dev-pandas', 'kubernetes-sigs-kueue', 'langchain-ai-langchain-google', 'jax-ml-jax', 'dask-dask', 'kubernetes-kubernetes', 'numpy-numpy', 'kubeflow-kubeflow', 'ray-project-ray', 'tensorflow-tensorflow', 'jupyterlab-jupyter-ai', 'microsoft-DeepSpeed', 'ipython-ipython', 'pytorch-pytorch', 'huggingface-transformers', 'langchain-ai-langchain-aws', 'langchain-ai-langchain', 'run-llama-llama_index', 'mlflow-mlflow', 'jupyterlab-jupyterlab', 'jupyter-server-jupyter-scheduler']

# %%
# Collect stats by project
df = pd.DataFrame(columns=["Project", "Start_Date", "End_Date", "p", "q", "m", "t", "T", "yrs"])
for project in projects_list:
    start_date, end_date, p, q, m, t, T, yrs = fit_bass.get_project_developer_model_stats(project)
    df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date, 
                                       "p": p, "q": q, "m": m, "t": t, "T": T, "yrs": yrs}])], ignore_index=True)
# Out:
# Project: vllm-project-vllm
# Number of periods: 36
# R² = 0.964903
# b0 = 13.864870 ± 5.551856 | t-stat = 2.4973
# b1 = 0.113969 ± 0.008304 | t-stat = 13.7243
# b2 = -1.051097e-05 ± 2.063545e-06 | t-stat = -5.0936
# p=0.001264671688656381, q=0.11523400326509994, m=10963.217066415064
# Time of zero growth: 106.16314119565197 months
# Remaining months = 70.16314119565197  = 5.846928432970998 years
# Project: scikit-learn-scikit-learn
# Number of periods: 193
# R² = 0.495492
# b0 = 16.352280 ± 1.825462 | t-stat = 8.9579
# b1 = 0.015162 ± 0.001280 | t-stat = 11.8420
# b2 = -1.677238e-06 ± 1.738680e-07 | t-stat = -9.6466
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_85517/240030380.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date,
# p=0.0016330249504921597, q=0.01679500461540637, m=10013.490687124287
# Time of zero growth: 451.99811744831874 months
# Remaining months = 258.99811744831874  = 21.58317645402656 years
# Project: pandas-dev-pandas
# Number of periods: 199
# R² = 0.720927
# b0 = 7.864429 ± 1.722086 | t-stat = 4.5668
# b1 = 0.026122 ± 0.001325 | t-stat = 19.7162
# b2 = -2.860440e-06 ± 1.766883e-07 | t-stat = -16.1892
# p=0.0008345153365556646, q=0.026956636976923923, m=9423.94837904027
# Time of zero growth: 351.29982740453835 months
# Remaining months = 152.29982740453835  = 12.691652283711528 years
# Project: kubernetes-sigs-kueue
# Number of periods: 51
# R² = 0.827523
# b0 = 5.403582 ± 1.156072 | t-stat = 4.6741
# b1 = 0.046122 ± 0.007607 | t-stat = 6.0628
# b2 = -1.750835e-05 ± 9.363402e-06 | t-stat = -1.8699
# p=0.0019673370170859013, q=0.048089265522755005, m=2746.6478088208523
# Time of zero growth: 176.72257958165366 months
# Remaining months = 125.72257958165366  = 10.476881631804472 years
# Project: langchain-ai-langchain-google
# Number of periods: 24
# R² = 0.143416
# b0 = 13.951723 ± 2.883668 | t-stat = 4.8382
# b1 = 0.033823 ± 0.036452 | t-stat = 0.9279
# b2 = -1.279938e-04 ± 9.831066e-05 | t-stat = -1.3019
# p=0.028604647012548494, q=0.06242811988947186, m=487.74323850747146
# Time of zero growth: 61.82854601232388 months
# Remaining months = 37.82854601232388  = 3.1523788343603236 years
# Project: jax-ml-jax
# Number of periods: 87
# R² = 0.809749
# b0 = 19.599079 ± 2.152621 | t-stat = 9.1048
# b1 = 0.015335 ± 0.003027 | t-stat = 5.0656
# b2 = 3.194460e-07 ± 8.439850e-07 | t-stat = 0.3785
# p=-0.014915492400635957, q=0.00041975459806346295, m=-1314.0081738899564
# Time of zero growth: -249.24959239451505 months
# Remaining months = -336.24959239451505  = -28.020799366209587 years
# Project: dask-dask
# Number of periods: 134
# R² = 0.695359
# b0 = 4.556806 ± 0.816674 | t-stat = 5.5797
# b1 = 0.036454 ± 0.002127 | t-stat = 17.1403
# b2 = -1.773517e-05 ± 1.031226e-06 | t-stat = -17.1981
# p=0.0020963881386289545, q=0.03854999360806058, m=2173.646273988758
# Time of zero growth: 199.97683431558548 months
# Remaining months = 65.97683431558548  = 5.4980695262987895 years
# Project: kubernetes-kubernetes
# Number of periods: 140
# R² = 0.626361
# b0 = 110.520327 ± 6.365117 | t-stat = 17.3634
# b1 = 0.017833 ± 0.001445 | t-stat = 12.3439
# b2 = -9.440362e-07 ± 6.678324e-08 | t-stat = -14.1358
# p=0.004642287487655737, q=0.022474953298780798, m=23807.299176592045
# Time of zero growth: 329.1996641556283 months
# Remaining months = 189.19966415562828  = 15.76663867963569 years
# Project: numpy-numpy
# Number of periods: 290
# R² = 0.877762
# b0 = 1.765299 ± 0.597395 | t-stat = 2.9550
# b1 = 0.017191 ± 0.000625 | t-stat = 27.4998
# b2 = -1.781851e-06 ± 1.080515e-07 | t-stat = -16.4908
# p=0.0001810635077416113, q=0.01737235420167326, m=9749.612769180536
# Time of zero growth: 592.7034569089757 months
# Remaining months = 302.7034569089757  = 25.225288075747972 years
# Project: kubeflow-kubeflow
# Number of periods: 99
# R² = 0.629518
# b0 = 19.931169 ± 1.949684 | t-stat = 10.2228
# b1 = 0.001106 ± 0.008404 | t-stat = 0.1316
# b2 = -2.598891e-05 ± 8.168012e-06 | t-stat = -3.1818
# p=0.02221313754257277, q=0.023319055627662674, m=897.2694014468069
# Time of zero growth: 112.189809959791 months
# Remaining months = 13.189809959791006  = 1.0991508299825838 years
# Project: ray-project-ray
# Number of periods: 120
# R² = 0.766513
# b0 = 12.721581 ± 2.243141 | t-stat = 5.6713
# b1 = 0.026795 ± 0.002623 | t-stat = 10.2141
# b2 = -2.838225e-06 ± 5.436820e-07 | t-stat = -5.2204
# p=0.0012858160339892643, q=0.028080776262152395, m=9893.779982777152
# Time of zero growth: 323.15891396642274 months
# Remaining months = 203.15891396642274  = 16.929909497201894 years
# Project: tensorflow-tensorflow
# Number of periods: 123
# R² = 0.717544
# b0 = 108.665500 ± 6.578288 | t-stat = 16.5188
# b1 = 0.023899 ± 0.001378 | t-stat = 17.3458
# b2 = -9.882675e-07 ± 5.715849e-08 | t-stat = -17.2900
# p=0.003867668744012109, q=0.027766230821431745, m=28095.865221876902
# Time of zero growth: 302.95310180362 months
# Remaining months = 179.95310180361997  = 14.996091816968331 years
# Project: jupyterlab-jupyter-ai
# Number of periods: 36
# R² = 0.440160
# b0 = 3.421156 ± 1.129500 | t-stat = 3.0289
# b1 = 0.102383 ± 0.023754 | t-stat = 4.3102
# b2 = -4.843984e-04 ± 1.001680e-04 | t-stat = -4.8359
# p=0.014213130214964743, q=0.1165965783465361, m=240.70389072743023
# Time of zero growth: 48.416520725679135 months
# Remaining months = 12.416520725679135  = 1.0347100604732613 years
# Project: microsoft-DeepSpeed
# Number of periods: 73
# R² = 0.676695
# b0 = 2.896076 ± 1.393149 | t-stat = 2.0788
# b1 = 0.068467 ± 0.005870 | t-stat = 11.6635
# b2 = -4.719516e-05 ± 4.464135e-06 | t-stat = -10.5721
# p=0.001941254897404873, q=0.07040845656410116, m=1491.8576577263293
# Time of zero growth: 124.17160498840737 months
# Remaining months = 51.17160498840737  = 4.264300415700614 years
# Project: ipython-ipython
# Number of periods: 247
# R² = 0.396460
# b0 = 4.190301 ± 0.884559 | t-stat = 4.7372
# b1 = 0.022811 ± 0.001823 | t-stat = 12.5116
# b2 = -8.625725e-06 ± 6.841073e-07 | t-stat = -12.6087
# p=0.001487504463153703, q=0.02429867237725799, m=2817.0005022567047
# Time of zero growth: 303.1972000402724 months
# Remaining months = 56.19720004027238  = 4.6831000033560315 years
# Project: pytorch-pytorch
# Number of periods: 169
# R² = 0.924165
# b0 = 21.872746 ± 3.286750 | t-stat = 6.6548
# b1 = 0.028882 ± 0.001099 | t-stat = 26.2734
# b2 = -8.639716e-07 ± 5.950036e-08 | t-stat = -14.5204
# p=0.0006401045416810708, q=0.029522414588479387, m=34170.58444117935
# Time of zero growth: 380.70049362633273 months
# Remaining months = 211.70049362633273  = 17.641707802194393 years
# Project: huggingface-transformers
# Number of periods: 88
# R² = 0.677504
# b0 = 29.603941 ± 4.793493 | t-stat = 6.1759
# b1 = 0.028741 ± 0.003704 | t-stat = 7.7596
# b2 = -2.432187e-06 ± 5.518965e-07 | t-stat = -4.4070
# p=0.002318252628722184, q=0.031058876608371436, m=12769.93762545647
# Time of zero growth: 282.01892941780693 months
# Remaining months = 194.01892941780693  = 16.16824411815058 years
# Project: langchain-ai-langchain-aws
# Number of periods: 23
# R² = 0.337070
# b0 = 4.594344 ± 1.623231 | t-stat = 2.8304
# b1 = 0.061894 ± 0.041237 | t-stat = 1.5009
# b2 = -1.525888e-04 ± 2.106315e-04 | t-stat = -0.7244
# p=0.009780946963265457, q=0.07167459277611835, m=469.72387543507443
# Time of zero growth: 78.98555061059777 months
# Remaining months = 55.98555061059777  = 4.665462550883148 years
# Project: langchain-ai-langchain
# Number of periods: 40
# R² = 0.749621
# b0 = 70.525741 ± 16.398431 | t-stat = 4.3008
# b1 = 0.133755 ± 0.015330 | t-stat = 8.7250
# b2 = -2.798558e-05 ± 2.830247e-06 | t-stat = -9.8880
# p=0.013411413688759678, q=0.14716598237711193, m=5258.635855571476
# Time of zero growth: 61.735828498386084 months
# Remaining months = 21.735828498386084  = 1.8113190415321736 years
# Project: run-llama-llama_index
# Number of periods: 39
# R² = 0.804302
# b0 = 22.622743 ± 5.902666 | t-stat = 3.8326
# b1 = 0.133897 ± 0.011119 | t-stat = 12.0417
# b2 = -4.726195e-05 ± 3.904759e-06 | t-stat = -12.1037
# p=0.007558519176421246, q=0.141455602584186, m=2993.012590769342
# Time of zero growth: 65.58239272706622 months
# Remaining months = 26.58239272706622  = 2.2151993939221852 years
# Project: mlflow-mlflow
# Number of periods: 92
# R² = 0.293828
# b0 = 17.052893 ± 2.090905 | t-stat = 8.1557
# b1 = 0.009437 ± 0.004470 | t-stat = 2.1112
# b2 = -1.182278e-06 ± 1.921172e-06 | t-stat = -0.6154
# p=0.0017949388365453222, q=0.01123228688618998, m=9500.542851658733
# Time of zero growth: 574.6891192488001 months
# Remaining months = 482.6891192488001  = 40.22409327073334 years
# Project: jupyterlab-jupyterlab
# Number of periods: 127
# R² = 0.466132
# b0 = 10.076285 ± 1.243663 | t-stat = 8.1021
# b1 = 0.026555 ± 0.002565 | t-stat = 10.3514
# b2 = -1.069506e-05 ± 1.040598e-06 | t-stat = -10.2778
# p=0.003576508835090674, q=0.03013173871895359, m=2817.3521236163124
# Time of zero growth: 221.92084647428618 months
# Remaining months = 94.92084647428618  = 7.910070539523848 years
# Project: jupyter-server-jupyter-scheduler
# Number of periods: 40
# R² = 0.567846
# b0 = 8.038868 ± 1.413919 | t-stat = 5.6855
# b1 = -0.110908 ± 0.053163 | t-stat = -2.0862
# b2 = 3.612120e-04 ± 4.423523e-04 | t-stat = 0.8166
# p=0.042361079013178926, q=-0.06854725081204592, m=189.77015238244573
# Time of zero growth: 47.53731219701726 months
# Remaining months = 7.537312197017258  = 0.6281093497514382 years

# %%
# TABLE II
# Export to Latex
df = df.sort_values(by="Project")
print(df.round(5).to_latex(float_format="%.5f", index=False))
# Out:
# \begin{tabular}{lllrrrlrr}
# \toprule
# Project & Start_Date & End_Date & p & q & m & t & T & yrs \\
# \midrule
# dask-dask & 2014-12-31 & 2026-01-31 & 0.00210 & 0.03855 & 2173.64627 & 134 & 199.97683 & 5.49807 \\
# huggingface-transformers & 2018-10-31 & 2026-01-31 & 0.00232 & 0.03106 & 12769.93763 & 88 & 282.01893 & 16.16824 \\
# ipython-ipython & 2005-07-31 & 2026-01-31 & 0.00149 & 0.02430 & 2817.00050 & 247 & 303.19720 & 4.68310 \\
# jax-ml-jax & 2018-11-30 & 2026-01-31 & -0.01492 & 0.00042 & -1314.00817 & 87 & -249.24959 & -28.02080 \\
# jupyter-server-jupyter-scheduler & 2022-09-30 & 2025-12-31 & 0.04236 & -0.06855 & 189.77015 & 40 & 47.53731 & 0.62811 \\
# jupyterlab-jupyter-ai & 2023-02-28 & 2026-01-31 & 0.01421 & 0.11660 & 240.70389 & 36 & 48.41652 & 1.03471 \\
# jupyterlab-jupyterlab & 2015-07-31 & 2026-01-31 & 0.00358 & 0.03013 & 2817.35212 & 127 & 221.92085 & 7.91007 \\
# kubeflow-kubeflow & 2017-11-30 & 2026-01-31 & 0.02221 & 0.02332 & 897.26940 & 99 & 112.18981 & 1.09915 \\
# kubernetes-kubernetes & 2014-06-30 & 2026-01-31 & 0.00464 & 0.02247 & 23807.29918 & 140 & 329.19966 & 15.76664 \\
# kubernetes-sigs-kueue & 2021-11-30 & 2026-01-31 & 0.00197 & 0.04809 & 2746.64781 & 51 & 176.72258 & 10.47688 \\
# langchain-ai-langchain & 2022-10-31 & 2026-01-31 & 0.01341 & 0.14717 & 5258.63586 & 40 & 61.73583 & 1.81132 \\
# langchain-ai-langchain-aws & 2024-03-31 & 2026-01-31 & 0.00978 & 0.07167 & 469.72388 & 23 & 78.98555 & 4.66546 \\
# langchain-ai-langchain-google & 2024-02-29 & 2026-01-31 & 0.02860 & 0.06243 & 487.74324 & 24 & 61.82855 & 3.15238 \\
# microsoft-DeepSpeed & 2020-01-31 & 2026-01-31 & 0.00194 & 0.07041 & 1491.85766 & 73 & 124.17160 & 4.26430 \\
# mlflow-mlflow & 2018-06-30 & 2026-01-31 & 0.00179 & 0.01123 & 9500.54285 & 92 & 574.68912 & 40.22409 \\
# numpy-numpy & 2001-12-31 & 2026-01-31 & 0.00018 & 0.01737 & 9749.61277 & 290 & 592.70346 & 25.22529 \\
# pandas-dev-pandas & 2009-07-31 & 2026-01-31 & 0.00083 & 0.02696 & 9423.94838 & 199 & 351.29983 & 12.69165 \\
# pytorch-pytorch & 2012-01-31 & 2026-01-31 & 0.00064 & 0.02952 & 34170.58444 & 169 & 380.70049 & 17.64171 \\
# ray-project-ray & 2016-02-29 & 2026-01-31 & 0.00129 & 0.02808 & 9893.77998 & 120 & 323.15891 & 16.92991 \\
# run-llama-llama_index & 2022-11-30 & 2026-01-31 & 0.00756 & 0.14146 & 2993.01259 & 39 & 65.58239 & 2.21520 \\
# scikit-learn-scikit-learn & 2010-01-31 & 2026-01-31 & 0.00163 & 0.01680 & 10013.49069 & 193 & 451.99812 & 21.58318 \\
# tensorflow-tensorflow & 2015-11-30 & 2026-01-31 & 0.00387 & 0.02777 & 28095.86522 & 123 & 302.95310 & 14.99609 \\
# vllm-project-vllm & 2023-02-28 & 2026-01-31 & 0.00126 & 0.11523 & 10963.21707 & 36 & 106.16314 & 5.84693 \\
# \bottomrule
# \end{tabular}

# %%
# Export to CSV
df.to_csv("notebooks/results/developer_stats.csv", index=False)
df = df.dropna()

# %%
# FIGURE 5
# Make combined plot of all projects
earliest_start = df['Start_Date'].min() # Get earliest start date of all projects
exclude_repos = ["jupyter-server-jupyter-scheduler", "jax-ml-jax"]

plt.figure(figsize=(15, 6))
start_datetime = pd.to_datetime(earliest_start)
color_num = 0
for index, row in df.iterrows():
    if row["Project"] not in exclude_repos:
        color_num += 1

        # Get time when series starts in span
        start_offset = months_between(earliest_start, row["Start_Date"])

        # Get the project life cycle so far
        t_list = np.arange(0, int(row["t"]))
        f, _ = fit_bass.bass(row["p"], row["q"], t_list)
        t_list = t_list + start_offset
        datetime_list = [start_datetime + pd.DateOffset(months=offset) for offset in t_list]
        plt.plot(datetime_list, f*row["m"], linewidth=2, label=row["Project"], color=plt.cm.tab20(color_num % 20))

        # Get the project life cycle from now to end
        t_list = np.arange(int(row["t"]), int(row["T"]))
        f, _ = fit_bass.bass(row["p"], row["q"], t_list)
        t_list = t_list + start_offset
        datetime_list = [start_datetime + pd.DateOffset(months=offset) for offset in t_list]
        plt.plot(datetime_list, f*row["m"], linewidth=2, ls='--', color=plt.cm.tab20(color_num % 20))
        plt.legend()
plt.xlabel('Date')
plt.ylabel('No. of Developers making contributions in each month')
plt.title('Developer engagement for selected projects')
plt.grid()
plt.savefig(f"notebooks/results/all_project_lifecycles.png")
plt.show()

# %%
df
# Out:
#                              Project  Start_Date    End_Date         p  \
# 6                          dask-dask  2014-12-31  2026-01-31  0.002096
# 16          huggingface-transformers  2018-10-31  2026-01-31  0.002318
# 14                   ipython-ipython  2005-07-31  2026-01-31  0.001488
# 5                         jax-ml-jax  2018-11-30  2026-01-31 -0.014915
# 22  jupyter-server-jupyter-scheduler  2022-09-30  2025-12-31  0.042361
# 12             jupyterlab-jupyter-ai  2023-02-28  2026-01-31  0.014213
# 21             jupyterlab-jupyterlab  2015-07-31  2026-01-31  0.003577
# 9                  kubeflow-kubeflow  2017-11-30  2026-01-31  0.022213
# 7              kubernetes-kubernetes  2014-06-30  2026-01-31  0.004642
# 3              kubernetes-sigs-kueue  2021-11-30  2026-01-31  0.001967
# 18            langchain-ai-langchain  2022-10-31  2026-01-31  0.013411
# 17        langchain-ai-langchain-aws  2024-03-31  2026-01-31  0.009781
# 4      langchain-ai-langchain-google  2024-02-29  2026-01-31  0.028605
# 13               microsoft-DeepSpeed  2020-01-31  2026-01-31  0.001941
# 20                     mlflow-mlflow  2018-06-30  2026-01-31  0.001795
# 8                        numpy-numpy  2001-12-31  2026-01-31  0.000181
# 2                  pandas-dev-pandas  2009-07-31  2026-01-31  0.000835
# 15                   pytorch-pytorch  2012-01-31  2026-01-31  0.000640
# 10                   ray-project-ray  2016-02-29  2026-01-31  0.001286
# 19             run-llama-llama_index  2022-11-30  2026-01-31  0.007559
# 1          scikit-learn-scikit-learn  2010-01-31  2026-01-31  0.001633
# 11             tensorflow-tensorflow  2015-11-30  2026-01-31  0.003868
# 0                  vllm-project-vllm  2023-02-28  2026-01-31  0.001265
#
#            q             m    t           T        yrs
# 6   0.038550   2173.646274  134  199.976834   5.498070
# 16  0.031059  12769.937625   88  282.018929  16.168244
# 14  0.024299   2817.000502  247  303.197200   4.683100
# 5   0.000420  -1314.008174   87 -249.249592 -28.020799
# 22 -0.068547    189.770152   40   47.537312   0.628109
# 12  0.116597    240.703891   36   48.416521   1.034710
# 21  0.030132   2817.352124  127  221.920846   7.910071
# 9   0.023319    897.269401   99  112.189810   1.099151
# 7   0.022475  23807.299177  140  329.199664  15.766639
# 3   0.048089   2746.647809   51  176.722580  10.476882
# 18  0.147166   5258.635856   40   61.735828   1.811319
# 17  0.071675    469.723875   23   78.985551   4.665463
# 4   0.062428    487.743239   24   61.828546   3.152379
# 13  0.070408   1491.857658   73  124.171605   4.264300
# 20  0.011232   9500.542852   92  574.689119  40.224093
# 8   0.017372   9749.612769  290  592.703457  25.225288
# 2   0.026957   9423.948379  199  351.299827  12.691652
# 15  0.029522  34170.584441  169  380.700494  17.641708
# 10  0.028081   9893.779983  120  323.158914  16.929909
# 19  0.141456   2993.012591   39   65.582393   2.215199
# 1   0.016795  10013.490687  193  451.998117  21.583176
# 11  0.027766  28095.865222  123  302.953102  14.996092
# 0   0.115234  10963.217066   36  106.163141   5.846928

# %%
# FIGURE 6 (new)
# Make normalized plot of all projects

plt.figure(figsize=(15, 6))
color_num = 0
for index, row in df.iterrows():
    if row["Project"] != "kubeflow-kubeflow": # the peak is at the start (edge case)
        color_num += 1
    
        # Get the peak time
        t0 = np.log(row["q"]/row["p"])/(row["p"]+row["q"])
    
        # Get lifespan
        T = row["T"]
        t_list = np.linspace(-5, T, 100)
        
        # Use Bass
        f, _ = fit_bass.bass(row["p"], row["q"], t_list)
        f0 = (row["p"] + row["q"])**2/(4*row["q"])
        plt.plot(t_list/t0, f/f0, linewidth=2, label=row["Project"], color=plt.cm.tab20(color_num % 20))
    
        plt.legend()
plt.xlabel('Normalized date relative to peak engagement')
plt.ylabel('Developer engagement each month (normalized)')
plt.title('Developer engagement for selected projects')
plt.grid()
plt.savefig(f"notebooks/results/all_project_lifecycles_normalized.png")
plt.show()
# Out:
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_85517/3053058953.py:11: RuntimeWarning: invalid value encountered in log
#   t0 = np.log(row["q"]/row["p"])/(row["p"]+row["q"])

# %% [markdown]
# ## Normalized Plot math
#
# $$
# \alpha = \ln(q/p)
# $$
#
#
# $$
# t_0 = \frac{\alpha}{p+q}
# $$
#
# $$
# f_0 = \frac{(p+q)^2}{4q}
# $$
#
# $$
# f = \frac{e^{(p+q)t} p (p+q)^2}{(p e^{(p+q)t} + q)^2}
# $$
#
# $$
# t1 = t/t_0
# $$
#
# $$
# f1 = f/f_0 = sech^2((\alpha/2)(1-t_1))
# $$

# %%
# Illustrate normalized math
project = "pandas-dev-pandas"
fn = "data/" + project + "-monthly.csv"
df1 = pd.read_csv(fn)
df1
# Out:
#      Unnamed: 0                       date  contributors  total_changes
# 0             0  2009-07-31 00:00:00+00:00             1              0
# 1             1  2009-08-31 00:00:00+00:00             1          21663
# 2             2  2009-09-30 00:00:00+00:00             1           2807
# 3             3  2009-10-31 00:00:00+00:00             1            975
# 4             4  2009-11-30 00:00:00+00:00             1          41097
# ..          ...                        ...           ...            ...
# 194         194  2025-09-30 00:00:00+00:00            40          10064
# 195         195  2025-10-31 00:00:00+00:00            89          16842
# 196         196  2025-11-30 00:00:00+00:00            54          12748
# 197         197  2025-12-31 00:00:00+00:00            61          10758
# 198         198  2026-01-31 00:00:00+00:00            38          28526
#
# [199 rows x 4 columns]

# %%
# Plot the sech(.) version of the formula against raw data for a single project
# Collect stats by project
df = pd.DataFrame(columns=["Project", "Start_Date", "End_Date", "p", "q", "m", "t", "T", "yrs"])
start_date, end_date, p, q, m, t, T, yrs = fit_bass.get_project_developer_model_stats(project)
df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date, 
                                       "p": p, "q": q, "m": m, "t": t, "T": T, "yrs": yrs}])], ignore_index=True) # `t` is #months of life, `T` is total forecast months

alpha = np.log(df["q"]/df["p"])
t0 = alpha/(p+q)
t1 = np.arange(t)
t2 = t1/t0[0]
f0 = (p + q)**2/(4*q)
f = fit_bass.bass(p,q,t1)[0]
f_new = f/f0

plt.plot(t1,f_new)

y = df1['contributors']
plt.scatter(t1, y/(f0*m))
plt.grid()
# Out:
# Project: pandas-dev-pandas
# Number of periods: 199
# R² = 0.720927
# b0 = 7.864429 ± 1.722086 | t-stat = 4.5668
# b1 = 0.026122 ± 0.001325 | t-stat = 19.7162
# b2 = -2.860440e-06 ± 1.766883e-07 | t-stat = -16.1892
# p=0.0008345153365556646, q=0.026956636976923923, m=9423.94837904027
# Time of zero growth: 351.29982740453835 months
# Remaining months = 152.29982740453835  = 12.691652283711528 years
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_85517/466024279.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date,
