# %% [markdown]
# # Generate all developer stats
#
# Collects model data about the developers in all projects.
# This gets the following for each project and creates a latex table:
# 1. p: coefficient of independent propensity to join the project
# 2. q: coefficient of network intensity to join the project
# 3. m: calibrated developer-months expected over the project's lifetime
# 4. t: current life of project in months
# 5. T: expected lifetime of project in months
# 6. yrs: expected remaining lifetime of project in years

# %%
import os
import numpy as np
import pandas as pd
import sys
sys.path.append('../oss_lifecycle')
import fit_bass
import matplotlib.pyplot as plt

# Months between two dates in YYYY-MM-DD str format
def months_between(start_date, end_date):
    start = pd.to_datetime(start_date)
    end = pd.to_datetime(end_date)
    return (end.year - start.year) * 12 + end.month - start.month

os.chdir('../')

# %%
# Get list of projects for which data files have been collected

project_files = os.listdir("data")
projects_list = []
for file in project_files:
    if file.endswith("-monthly.csv"):
        projects_list.append(file.split("-monthly")[0])

print("Projects:", projects_list)
# Out:
# Projects: ['vllm-project-vllm', 'scikit-learn-scikit-learn', 'pandas-dev-pandas', 'kubernetes-sigs-kueue', 'langchain-ai-langchain-google', 'jax-ml-jax', 'dask-dask', 'kubernetes-kubernetes', 'numpy-numpy', 'kubeflow-kubeflow', 'ray-project-ray', 'tensorflow-tensorflow', 'jupyterlab-jupyter-ai', 'microsoft-DeepSpeed', 'ipython-ipython', 'pytorch-pytorch', 'huggingface-transformers', 'langchain-ai-langchain-aws', 'langchain-ai-langchain', 'run-llama-llama_index', 'mlflow-mlflow', 'jupyterlab-jupyterlab', 'jupyter-server-jupyter-scheduler']

# %%
# Collect stats by project
df = pd.DataFrame(columns=["Project", "Start_Date", "End_Date", "p", "q", "m", "t", "T", "yrs"])
for project in projects_list:
    start_date, end_date, p, q, m, t, T, yrs = fit_bass.get_project_developer_model_stats(project)
    df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date, 
                                       "p": p, "q": q, "m": m, "t": t, "T": T, "yrs": yrs}])], ignore_index=True)
# Out:
# Project: vllm-project-vllm
# Number of periods: 36
# R² = 0.972371
# b0 = 14.953358 ± 4.991659 | t-stat = 2.9957
# b1 = 0.109798 ± 0.007435 | t-stat = 14.7671
# b2 = -9.001882e-06 ± 1.841692e-06 | t-stat = -4.8878
# p=0.001212573286998195, q=0.11101049307884714, m=12331.921161516446
# Time of zero growth: 110.96520409819804 months
# Remaining months = 74.96520409819804  = 6.247100341516504 years
# Project: scikit-learn-scikit-learn
# Number of periods: 193
# R² = 0.495311
# b0 = 16.371754 ± 1.825630 | t-stat = 8.9677
# b1 = 0.015134 ± 0.001280 | t-stat = 11.8195
# b2 = -1.672235e-06 ± 1.738785e-07 | t-stat = -9.6173
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_7180/240030380.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date,
# p=0.0016328047556699774, q=0.016767108744645404, m=10026.76781831417
# Time of zero growth: 452.6021526952483 months
# Remaining months = 259.6021526952483  = 21.633512724604028 years
# Project: pandas-dev-pandas
# Number of periods: 199
# R² = 0.719817
# b0 = 7.916946 ± 1.725657 | t-stat = 4.5878
# b1 = 0.026022 ± 0.001328 | t-stat = 19.6020
# b2 = -2.842782e-06 ± 1.770313e-07 | t-stat = -16.0581
# p=0.0008378949010358415, q=0.026860353435202933, m=9448.615102836156
# Time of zero growth: 352.1847454396922 months
# Remaining months = 153.18474543969222  = 12.765395453307685 years
# Project: kubernetes-sigs-kueue
# Number of periods: 51
# R² = 0.829405
# b0 = 5.440556 ± 1.152965 | t-stat = 4.7188
# b1 = 0.045607 ± 0.007584 | t-stat = 6.0137
# b2 = -1.664636e-05 ± 9.331576e-06 | t-stat = -1.7839
# p=0.0019061180408774265, q=0.04751302184102905, m=2854.25958694921
# Time of zero growth: 179.90429279905467 months
# Remaining months = 128.90429279905467  = 10.742024399921222 years
# Project: langchain-ai-langchain-google
# Number of periods: 24
# R² = 0.127382
# b0 = 14.064548 ± 2.903201 | t-stat = 4.8445
# b1 = 0.031251 ± 0.036655 | t-stat = 0.8526
# b2 = -1.189815e-04 ± 9.877359e-05 | t-stat = -1.2046
# p=0.028164744928825976, q=0.0594154341682138, m=499.3671272480433
# Time of zero growth: 63.82809752098398 months
# Remaining months = 39.82809752098398  = 3.319008126748665 years
# Project: jax-ml-jax
# Number of periods: 87
# R² = 0.815667
# b0 = 19.693453 ± 2.125020 | t-stat = 9.2674
# b1 = 0.015062 ± 0.002987 | t-stat = 5.0423
# b2 = 4.290718e-07 ± 8.324303e-07 | t-stat = 0.5154
# p=-0.01447843608703594, q=0.0005836200379790556, m=-1360.1919950034649
# Time of zero growth: -258.61177428167105 months
# Remaining months = -345.61177428167105  = -28.800981190139254 years
# Project: dask-dask
# Number of periods: 134
# R² = 0.695359
# b0 = 4.556806 ± 0.816674 | t-stat = 5.5797
# b1 = 0.036454 ± 0.002127 | t-stat = 17.1403
# b2 = -1.773517e-05 ± 1.031226e-06 | t-stat = -17.1981
# p=0.0020963881386289545, q=0.03854999360806058, m=2173.646273988758
# Time of zero growth: 199.97683431558548 months
# Remaining months = 65.97683431558548  = 5.4980695262987895 years
# Project: kubernetes-kubernetes
# Number of periods: 140
# R² = 0.619899
# b0 = 110.831610 ± 6.389113 | t-stat = 17.3469
# b1 = 0.017691 ± 0.001450 | t-stat = 12.2014
# b2 = -9.355498e-07 ± 6.702084e-08 | t-stat = -13.9591
# p=0.004642703721547291, q=0.022333644313307408, m=23872.212576056132
# Time of zero growth: 330.6303560327003 months
# Remaining months = 190.63035603270032  = 15.885863002725026 years
# Project: numpy-numpy
# Number of periods: 290
# R² = 0.878091
# b0 = 1.777151 ± 0.596772 | t-stat = 2.9779
# b1 = 0.017164 ± 0.000624 | t-stat = 27.4858
# b2 = -1.775518e-06 ± 1.079346e-07 | t-stat = -16.4499
# p=0.00018190601656484885, q=0.017346115834259067, m=9769.609119037801
# Time of zero growth: 593.2492693159464 months
# Remaining months = 303.24926931594644  = 25.270772442995536 years
# Project: kubeflow-kubeflow
# Number of periods: 99
# R² = 0.629518
# b0 = 19.931169 ± 1.949684 | t-stat = 10.2228
# b1 = 0.001106 ± 0.008404 | t-stat = 0.1316
# b2 = -2.598891e-05 ± 8.168012e-06 | t-stat = -3.1818
# p=0.02221313754257277, q=0.023319055627662674, m=897.2694014468069
# Time of zero growth: 112.189809959791 months
# Remaining months = 13.189809959791006  = 1.0991508299825838 years
# Project: ray-project-ray
# Number of periods: 120
# R² = 0.762465
# b0 = 12.930929 ± 2.281002 | t-stat = 5.6690
# b1 = 0.026224 ± 0.002666 | t-stat = 9.8357
# b2 = -2.685660e-06 ± 5.524197e-07 | t-stat = -4.8616
# p=0.001263403187042614, q=0.02748772150222492, m=10234.99818424214
# Time of zero growth: 330.39570425962455 months
# Remaining months = 210.39570425962455  = 17.532975354968713 years
# Project: tensorflow-tensorflow
# Number of periods: 123
# R² = 0.714510
# b0 = 108.853483 ± 6.602877 | t-stat = 16.4858
# b1 = 0.023819 ± 0.001383 | t-stat = 17.2243
# b2 = -9.839617e-07 ± 5.736740e-08 | t-stat = -17.1519
# p=0.0038684892753410873, q=0.027687206772486497, m=28138.49943799347
# Time of zero growth: 303.58833384957353 months
# Remaining months = 180.58833384957353  = 15.049027820797795 years
# Project: jupyterlab-jupyter-ai
# Number of periods: 36
# R² = 0.440160
# b0 = 3.421156 ± 1.129500 | t-stat = 3.0289
# b1 = 0.102383 ± 0.023754 | t-stat = 4.3102
# b2 = -4.843984e-04 ± 1.001680e-04 | t-stat = -4.8359
# p=0.014213130214964743, q=0.1165965783465361, m=240.70389072743023
# Time of zero growth: 48.416520725679135 months
# Remaining months = 12.416520725679135  = 1.0347100604732613 years
# Project: microsoft-DeepSpeed
# Number of periods: 73
# R² = 0.675286
# b0 = 2.948832 ± 1.393103 | t-stat = 2.1167
# b1 = 0.068058 ± 0.005869 | t-stat = 11.5969
# b2 = -4.678673e-05 ± 4.462222e-06 | t-stat = -10.4851
# p=0.0019701647644434508, q=0.07002775506245884, m=1496.7439993002959
# Time of zero growth: 124.48288929867086 months
# Remaining months = 51.482889298670855  = 4.290240774889238 years
# Project: ipython-ipython
# Number of periods: 247
# R² = 0.396460
# b0 = 4.190301 ± 0.884559 | t-stat = 4.7372
# b1 = 0.022811 ± 0.001823 | t-stat = 12.5116
# b2 = -8.625725e-06 ± 6.841073e-07 | t-stat = -12.6087
# p=0.001487504463153703, q=0.02429867237725799, m=2817.0005022567047
# Time of zero growth: 303.1972000402724 months
# Remaining months = 56.19720004027238  = 4.6831000033560315 years
# Project: pytorch-pytorch
# Number of periods: 169
# R² = 0.923807
# b0 = 22.052585 ± 3.301642 | t-stat = 6.6793
# b1 = 0.028693 ± 0.001104 | t-stat = 25.9889
# b2 = -8.501200e-07 ± 5.975080e-08 | t-stat = -14.2278
# p=0.0006391355823644111, q=0.029332344037759243, m=34503.7672081345
# Time of zero growth: 383.0775109616482 months
# Remaining months = 214.07751096164822  = 17.839792580137352 years
# Project: huggingface-transformers
# Number of periods: 88
# R² = 0.681678
# b0 = 29.762653 ± 4.763024 | t-stat = 6.2487
# b1 = 0.028477 ± 0.003680 | t-stat = 7.7392
# b2 = -2.378373e-06 ± 5.481981e-07 | t-stat = -4.3385
# p=0.002299987395869375, q=0.03077699347551261, m=12940.354949204473
# Time of zero growth: 284.6720531746458 months
# Remaining months = 196.67205317464578  = 16.389337764553815 years
# Project: langchain-ai-langchain-aws
# Number of periods: 23
# R² = 0.354509
# b0 = 4.688290 ± 1.606323 | t-stat = 2.9186
# b1 = 0.057534 ± 0.040698 | t-stat = 1.4137
# b2 = -1.224459e-04 ± 2.074479e-04 | t-stat = -0.5902
# p=0.008671020561156888, q=0.06620464962282956, m=540.6849350505121
# Time of zero growth: 87.18042768023666 months
# Remaining months = 64.18042768023666  = 5.348368973353055 years
# Project: langchain-ai-langchain
# Number of periods: 40
# R² = 0.746970
# b0 = 70.711373 ± 16.451112 | t-stat = 4.2983
# b1 = 0.133325 ± 0.015375 | t-stat = 8.6713
# b2 = -2.788140e-05 ± 2.838252e-06 | t-stat = -9.8234
# p=0.013433781560190629, q=0.14675927992516863, m=5263.698269608321
# Time of zero growth: 61.84962369260224 months
# Remaining months = 21.849623692602243  = 1.8208019743835202 years
# Project: run-llama-llama_index
# Number of periods: 39
# R² = 0.785488
# b0 = 23.224984 ± 6.132748 | t-stat = 3.7870
# b1 = 0.131442 ± 0.011536 | t-stat = 11.3938
# b2 = -4.615284e-05 ± 4.047902e-06 | t-stat = -11.4017
# p=0.007703440789061943, q=0.13914547442033137, m=3014.8844239161203
# Time of zero growth: 66.27019656572125 months
# Remaining months = 27.27019656572125  = 2.272516380476771 years
# Project: mlflow-mlflow
# Number of periods: 92
# R² = 0.298516
# b0 = 17.189505 ± 2.099924 | t-stat = 8.1858
# b1 = 0.008946 ± 0.004488 | t-stat = 1.9932
# b2 = -9.100091e-07 ± 1.928569e-06 | t-stat = -0.4719
# p=0.001497791200991726, q=0.010443783028921592, m=11476.569545468961
# Time of zero growth: 643.3911223951985 months
# Remaining months = 551.3911223951985  = 45.94926019959988 years
# Project: jupyterlab-jupyterlab
# Number of periods: 127
# R² = 0.463826
# b0 = 10.089616 ± 1.246325 | t-stat = 8.0955
# b1 = 0.026495 ± 0.002571 | t-stat = 10.3063
# b2 = -1.066320e-05 ± 1.042757e-06 | t-stat = -10.2260
# p=0.003577598548142592, q=0.030072565028045325, m=2820.2203697974105
# Time of zero growth: 222.2224572844254 months
# Remaining months = 95.22245728442539  = 7.935204773702115 years
# Project: jupyter-server-jupyter-scheduler
# Number of periods: 40
# R² = 0.567846
# b0 = 8.038868 ± 1.413919 | t-stat = 5.6855
# b1 = -0.110908 ± 0.053163 | t-stat = -2.0862
# b2 = 3.612120e-04 ± 4.423523e-04 | t-stat = 0.8166
# p=0.042361079013178926, q=-0.06854725081204592, m=189.77015238244573
# Time of zero growth: 47.53731219701726 months
# Remaining months = 7.537312197017258  = 0.6281093497514382 years

# %%
# TABLE II
# Export to Latex
df = df.sort_values(by="Project")
print(df.round(5).to_latex(float_format="%.5f", index=False))
# Out:
# \begin{tabular}{lllrrrlrr}
# \toprule
# Project & Start_Date & End_Date & p & q & m & t & T & yrs \\
# \midrule
# dask-dask & 2014-12-31 & 2026-01-31 & 0.00210 & 0.03855 & 2173.64627 & 134 & 199.97683 & 5.49807 \\
# huggingface-transformers & 2018-10-31 & 2026-01-31 & 0.00230 & 0.03078 & 12940.35495 & 88 & 284.67205 & 16.38934 \\
# ipython-ipython & 2005-07-31 & 2026-01-31 & 0.00149 & 0.02430 & 2817.00050 & 247 & 303.19720 & 4.68310 \\
# jax-ml-jax & 2018-11-30 & 2026-01-31 & -0.01448 & 0.00058 & -1360.19200 & 87 & -258.61177 & -28.80098 \\
# jupyter-server-jupyter-scheduler & 2022-09-30 & 2025-12-31 & 0.04236 & -0.06855 & 189.77015 & 40 & 47.53731 & 0.62811 \\
# jupyterlab-jupyter-ai & 2023-02-28 & 2026-01-31 & 0.01421 & 0.11660 & 240.70389 & 36 & 48.41652 & 1.03471 \\
# jupyterlab-jupyterlab & 2015-07-31 & 2026-01-31 & 0.00358 & 0.03007 & 2820.22037 & 127 & 222.22246 & 7.93520 \\
# kubeflow-kubeflow & 2017-11-30 & 2026-01-31 & 0.02221 & 0.02332 & 897.26940 & 99 & 112.18981 & 1.09915 \\
# kubernetes-kubernetes & 2014-06-30 & 2026-01-31 & 0.00464 & 0.02233 & 23872.21258 & 140 & 330.63036 & 15.88586 \\
# kubernetes-sigs-kueue & 2021-11-30 & 2026-01-31 & 0.00191 & 0.04751 & 2854.25959 & 51 & 179.90429 & 10.74202 \\
# langchain-ai-langchain & 2022-10-31 & 2026-01-31 & 0.01343 & 0.14676 & 5263.69827 & 40 & 61.84962 & 1.82080 \\
# langchain-ai-langchain-aws & 2024-03-31 & 2026-01-31 & 0.00867 & 0.06620 & 540.68494 & 23 & 87.18043 & 5.34837 \\
# langchain-ai-langchain-google & 2024-02-29 & 2026-01-31 & 0.02816 & 0.05942 & 499.36713 & 24 & 63.82810 & 3.31901 \\
# microsoft-DeepSpeed & 2020-01-31 & 2026-01-31 & 0.00197 & 0.07003 & 1496.74400 & 73 & 124.48289 & 4.29024 \\
# mlflow-mlflow & 2018-06-30 & 2026-01-31 & 0.00150 & 0.01044 & 11476.56955 & 92 & 643.39112 & 45.94926 \\
# numpy-numpy & 2001-12-31 & 2026-01-31 & 0.00018 & 0.01735 & 9769.60912 & 290 & 593.24927 & 25.27077 \\
# pandas-dev-pandas & 2009-07-31 & 2026-01-31 & 0.00084 & 0.02686 & 9448.61510 & 199 & 352.18475 & 12.76540 \\
# pytorch-pytorch & 2012-01-31 & 2026-01-31 & 0.00064 & 0.02933 & 34503.76721 & 169 & 383.07751 & 17.83979 \\
# ray-project-ray & 2016-02-29 & 2026-01-31 & 0.00126 & 0.02749 & 10234.99818 & 120 & 330.39570 & 17.53298 \\
# run-llama-llama_index & 2022-11-30 & 2026-01-31 & 0.00770 & 0.13915 & 3014.88442 & 39 & 66.27020 & 2.27252 \\
# scikit-learn-scikit-learn & 2010-01-31 & 2026-01-31 & 0.00163 & 0.01677 & 10026.76782 & 193 & 452.60215 & 21.63351 \\
# tensorflow-tensorflow & 2015-11-30 & 2026-01-31 & 0.00387 & 0.02769 & 28138.49944 & 123 & 303.58833 & 15.04903 \\
# vllm-project-vllm & 2023-02-28 & 2026-01-31 & 0.00121 & 0.11101 & 12331.92116 & 36 & 110.96520 & 6.24710 \\
# \bottomrule
# \end{tabular}

# %%
# Export to CSV
df.to_csv("notebooks/results/developer_stats.csv", index=False)
df = df.dropna()

# %%
# FIGURE 5
# Make combined plot of all projects
earliest_start = df['Start_Date'].min() # Get earliest start date of all projects
exclude_repos = ["jupyter-server-jupyter-scheduler", "jax-ml-jax"]

plt.figure(figsize=(15, 6))
start_datetime = pd.to_datetime(earliest_start)
color_num = 0
for index, row in df.iterrows():
    if row["Project"] not in exclude_repos:
        color_num += 1

        # Get time when series starts in span
        start_offset = months_between(earliest_start, row["Start_Date"])

        # Get the project life cycle so far
        t_list = np.arange(0, int(row["t"]))
        f, _ = fit_bass.bass(row["p"], row["q"], t_list)
        t_list = t_list + start_offset
        datetime_list = [start_datetime + pd.DateOffset(months=offset) for offset in t_list]
        plt.plot(datetime_list, f*row["m"], linewidth=2, label=row["Project"], color=plt.cm.tab20(color_num % 20))

        # Get the project life cycle from now to end
        t_list = np.arange(int(row["t"]), int(row["T"]))
        f, _ = fit_bass.bass(row["p"], row["q"], t_list)
        t_list = t_list + start_offset
        datetime_list = [start_datetime + pd.DateOffset(months=offset) for offset in t_list]
        plt.plot(datetime_list, f*row["m"], linewidth=2, ls='--', color=plt.cm.tab20(color_num % 20))
        plt.legend()
plt.xlabel('Date')
plt.ylabel('No. of Developers making contributions in each month')
plt.title('Developer engagement for selected projects')
plt.grid()
plt.savefig(f"notebooks/results/all_project_lifecycles.png")
plt.show()

# %%
df
# Out:
#                              Project  Start_Date    End_Date         p  \
# 6                          dask-dask  2014-12-31  2026-01-31  0.002096
# 16          huggingface-transformers  2018-10-31  2026-01-31  0.002300
# 14                   ipython-ipython  2005-07-31  2026-01-31  0.001488
# 5                         jax-ml-jax  2018-11-30  2026-01-31 -0.014478
# 22  jupyter-server-jupyter-scheduler  2022-09-30  2025-12-31  0.042361
# 12             jupyterlab-jupyter-ai  2023-02-28  2026-01-31  0.014213
# 21             jupyterlab-jupyterlab  2015-07-31  2026-01-31  0.003578
# 9                  kubeflow-kubeflow  2017-11-30  2026-01-31  0.022213
# 7              kubernetes-kubernetes  2014-06-30  2026-01-31  0.004643
# 3              kubernetes-sigs-kueue  2021-11-30  2026-01-31  0.001906
# 18            langchain-ai-langchain  2022-10-31  2026-01-31  0.013434
# 17        langchain-ai-langchain-aws  2024-03-31  2026-01-31  0.008671
# 4      langchain-ai-langchain-google  2024-02-29  2026-01-31  0.028165
# 13               microsoft-DeepSpeed  2020-01-31  2026-01-31  0.001970
# 20                     mlflow-mlflow  2018-06-30  2026-01-31  0.001498
# 8                        numpy-numpy  2001-12-31  2026-01-31  0.000182
# 2                  pandas-dev-pandas  2009-07-31  2026-01-31  0.000838
# 15                   pytorch-pytorch  2012-01-31  2026-01-31  0.000639
# 10                   ray-project-ray  2016-02-29  2026-01-31  0.001263
# 19             run-llama-llama_index  2022-11-30  2026-01-31  0.007703
# 1          scikit-learn-scikit-learn  2010-01-31  2026-01-31  0.001633
# 11             tensorflow-tensorflow  2015-11-30  2026-01-31  0.003868
# 0                  vllm-project-vllm  2023-02-28  2026-01-31  0.001213
#
#            q             m    t           T        yrs
# 6   0.038550   2173.646274  134  199.976834   5.498070
# 16  0.030777  12940.354949   88  284.672053  16.389338
# 14  0.024299   2817.000502  247  303.197200   4.683100
# 5   0.000584  -1360.191995   87 -258.611774 -28.800981
# 22 -0.068547    189.770152   40   47.537312   0.628109
# 12  0.116597    240.703891   36   48.416521   1.034710
# 21  0.030073   2820.220370  127  222.222457   7.935205
# 9   0.023319    897.269401   99  112.189810   1.099151
# 7   0.022334  23872.212576  140  330.630356  15.885863
# 3   0.047513   2854.259587   51  179.904293  10.742024
# 18  0.146759   5263.698270   40   61.849624   1.820802
# 17  0.066205    540.684935   23   87.180428   5.348369
# 4   0.059415    499.367127   24   63.828098   3.319008
# 13  0.070028   1496.743999   73  124.482889   4.290241
# 20  0.010444  11476.569545   92  643.391122  45.949260
# 8   0.017346   9769.609119  290  593.249269  25.270772
# 2   0.026860   9448.615103  199  352.184745  12.765395
# 15  0.029332  34503.767208  169  383.077511  17.839793
# 10  0.027488  10234.998184  120  330.395704  17.532975
# 19  0.139145   3014.884424   39   66.270197   2.272516
# 1   0.016767  10026.767818  193  452.602153  21.633513
# 11  0.027687  28138.499438  123  303.588334  15.049028
# 0   0.111010  12331.921162   36  110.965204   6.247100

# %%
# FIGURE 6 (new)
# Make normalized plot of all projects

plt.figure(figsize=(15, 6))
color_num = 0
for index, row in df.iterrows():
    if row["Project"] != "kubeflow-kubeflow": # the peak is at the start (edge case)
        color_num += 1
    
        # Get the peak time
        t0 = np.log(row["q"]/row["p"])/(row["p"]+row["q"])
    
        # Get lifespan
        T = row["T"]
        t_list = np.linspace(-5, T, 100)
        
        # Use Bass
        f, _ = fit_bass.bass(row["p"], row["q"], t_list)
        f0 = (row["p"] + row["q"])**2/(4*row["q"])
        plt.plot(t_list/t0, f/f0, linewidth=2, label=row["Project"], color=plt.cm.tab20(color_num % 20))
    
        plt.legend()
plt.xlabel('Normalized date relative to peak engagement')
plt.ylabel('Developer engagement each month (normalized)')
plt.title('Developer engagement for selected projects')
plt.grid()
plt.savefig(f"notebooks/results/all_project_lifecycles_normalized.png")
plt.show()
# Out:
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_7180/3053058953.py:11: RuntimeWarning: invalid value encountered in log
#   t0 = np.log(row["q"]/row["p"])/(row["p"]+row["q"])

# %% [markdown]
# ## Normalized Plot math
#
# $$
# \alpha = \ln(q/p)
# $$
#
#
# $$
# t_0 = \frac{\alpha}{p+q}
# $$
#
# $$
# f_0 = \frac{(p+q)^2}{4q}
# $$
#
# $$
# f = \frac{e^{(p+q)t} p (p+q)^2}{(p e^{(p+q)t} + q)^2}
# $$
#
# $$
# t1 = t/t_0
# $$
#
# $$
# f1 = f/f_0 = sech^2((\alpha/2)(1-t_1))
# $$

# %%
# Illustrate normalized math
project = "pandas-dev-pandas"
fn = "data/" + project + "-monthly.csv"
df1 = pd.read_csv(fn)
df1
# Out:
#      Unnamed: 0                       date  contributors  total_changes
# 0             0  2009-07-31 00:00:00+00:00             1              0
# 1             1  2009-08-31 00:00:00+00:00             1          21663
# 2             2  2009-09-30 00:00:00+00:00             1           2807
# 3             3  2009-10-31 00:00:00+00:00             1            975
# 4             4  2009-11-30 00:00:00+00:00             1          41097
# ..          ...                        ...           ...            ...
# 194         194  2025-09-30 00:00:00+00:00            40          10064
# 195         195  2025-10-31 00:00:00+00:00            89          16842
# 196         196  2025-11-30 00:00:00+00:00            54          12748
# 197         197  2025-12-31 00:00:00+00:00            61          10758
# 198         198  2026-01-31 00:00:00+00:00            46          29741
#
# [199 rows x 4 columns]

# %%
# Plot the sech(.) version of the formula against raw data for a single project
# Collect stats by project
df = pd.DataFrame(columns=["Project", "Start_Date", "End_Date", "p", "q", "m", "t", "T", "yrs"])
start_date, end_date, p, q, m, t, T, yrs = fit_bass.get_project_developer_model_stats(project)
df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date, 
                                       "p": p, "q": q, "m": m, "t": t, "T": T, "yrs": yrs}])], ignore_index=True) # `t` is #months of life, `T` is total forecast months

alpha = np.log(df["q"]/df["p"])
t0 = alpha/(p+q)
t1 = np.arange(t)
t2 = t1/t0[0]
f0 = (p + q)**2/(4*q)
f = fit_bass.bass(p,q,t1)[0]
f_new = f/f0

plt.plot(t1,f_new)

y = df1['contributors']
plt.scatter(t1, y/(f0*m))
plt.grid()
# Out:
# Project: pandas-dev-pandas
# Number of periods: 199
# R² = 0.719817
# b0 = 7.916946 ± 1.725657 | t-stat = 4.5878
# b1 = 0.026022 ± 0.001328 | t-stat = 19.6020
# b2 = -2.842782e-06 ± 1.770313e-07 | t-stat = -16.0581
# p=0.0008378949010358415, q=0.026860353435202933, m=9448.615102836156
# Time of zero growth: 352.1847454396922 months
# Remaining months = 153.18474543969222  = 12.765395453307685 years
# /var/folders/39/_tms02415nx6vyczz78csvl80000gr/T/ipykernel_7180/466024279.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame([{"Project": project, "Start_Date":start_date, "End_Date":end_date,
